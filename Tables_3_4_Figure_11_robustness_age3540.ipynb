# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.optimize import fsolve

sn.set_style('whitegrid')
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:65: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
# Expanded and modified version (first column now string)
def read_table(filename,keyword='ciclo',rescale=1,ncols=5,start=2,end_row='Total',
               endword=None,omit_list=['t20_21'],index_to_int=True,debug=False):
    t0 = start
    t1 = ncols+start
    results_follow = 0
    row_names = []
    f = open(filename,'r')
    for line in f:
        words = line.split()
        if debug:
            print(words)
        if len(words)>1 and words[0] == keyword:
            results_follow=1
            if endword==None:
                colnames = words[t0:t1]
            else:
                buff_v = []
                for w in words[t0:]:
                    if w==endword:
                        break
                    else:
                        buff_v.append(w)
                colnames = buff_v[:-1]
                t1 = len(buff_v)+t0-1
            table_raw = np.empty(t1-t0)
        elif len(words)>1 and words[0] == end_row:
            break
        elif len(words)>1 and results_follow==1 and words[0] not in omit_list:
            row_names.append(words[0])
            buff_v = []
            for w in words[t0:t1]: 
                w = w.replace(",","")
                buff_v.append(w)
            table_raw = np.vstack((table_raw,np.array(buff_v,dtype=float)/rescale))
    table_raw = table_raw[1:,:]
    if debug:
        print(table_raw.shape)
        print(colnames)
    if index_to_int:
        return pd.DataFrame(table_raw, columns=colnames,index=np.array(row_names,dtype=int))
    else:
        return pd.DataFrame(table_raw, columns=colnames,index=np.array(row_names))
    
    
def file_split(filename,path,startwords=['Summary',],endword="Total",header=None):
    f = open(path+filename,'r')
    parent_file = filename[:filename.find('.')]
    di = 1
    writing = 0
    for line in f:
        words = line.split()
        if len(words)>0 and words[0] in startwords:
            sf = open(path+parent_file+'_{}.log'.format(di), "w")
            writing = 1
            if header!=None:
                sf.write(header)
        elif len(words)>0 and words[0]==endword and writing:
            sf.write(line)
            writing = 0
            sf.close()
            di+=1
        if writing:
            sf.write(line)
            
def normalise_table(table):
    cols = table.columns
    table['Total'] = table.sum(axis=1).copy()
    for col in cols:
        table[col] = table[col]/table['Total']
    return table

# %%
dates = []
for year in range(1987,2023):
    for quarter in range(1,5):
        dates.append(str(year)+"Q"+str(quarter))
dates = dates[1:]

t0 = 59
t05 = 71
T = len(dates)
date_dict = dict(zip(range(t0,T+t0),dates))
date_dict_reverse = dict(zip(dates,range(0,T)))
date_dict_reverse_ciclo = dict(zip(dates,range(t0,T+t0)))

# %%
industry_dict = {"0": "agriculture", "1" :"manufactures, primary", "2": "extractive and energy", "3": "manufactures, secondary",
                 "4": "construction", "5": "hospitality and sales", "6": "Transport, storage and IT.",
                 "7": "Financial and prof. serv.", "8": "Education and healthcare", "9": "Other services"}

# %%
path = 'descriptive_stats/'

file_split('stocks_E_industry_w.log',path,startwords=['ciclo',],endword="Total",header=None)

# %%
tab_e_ind_1 = read_table(path+'stocks_E_industry_w_1.log',keyword='ciclo',rescale=100,ncols=6)
tab_e_ind_2 = read_table(path+'stocks_E_industry_w_2.log',keyword='ciclo',rescale=100,ncols=4)
tab_e_ind = pd.concat((tab_e_ind_1,tab_e_ind_2),axis=1)
tab_e_ind.rename(columns=industry_dict,inplace=True)
tab_e_ind.rename(index=date_dict,inplace=True)
tab_e_ind.head()
# Out:
#         agriculture  manufactures, primary  extractive and energy  \
# 2005Q1    473715.07              994533.00             1035476.59
# 2005Q2    499959.89             1007007.37             1051515.39
# 2005Q3    506896.23             1006269.15             1076158.88
# 2005Q4    525850.30             1009786.14             1086961.30
# 2006Q1    508519.95              969445.08             1088810.74
#
#         manufactures, secondary  construction  hospitality and sales  \
# 2005Q1                839644.48    1814072.71             2915322.75
# 2005Q2                846258.53    1875225.69             3067829.12
# 2005Q3                870718.23    1920187.68             3143106.60
# 2005Q4                824566.82    1939860.91             3144373.66
# 2006Q1                849166.47    1947958.32             3102377.87
#
#         Transport, storage and IT.  Financial and prof. serv.  \
# 2005Q1                   891234.56                 1673224.13
# 2005Q2                   893954.68                 1785085.40
# 2005Q3                   920963.75                 1794988.45
# 2005Q4                   908474.94                 1847232.28
# 2006Q1                   913945.53                 1874000.16
#
#         Education and healthcare  Other services
# 2005Q1                3301773.86      1272331.89
# 2005Q2                3348945.49      1313956.69
# 2005Q3                3355164.74      1374849.44
# 2005Q4                3409273.70      1328851.90
# 2006Q1                3435714.02      1378562.25

# %%
av_19 = np.average(tab_e_ind.loc['2019Q1':'2019Q4',:].values,axis=0)
diff = tab_e_ind.iloc[1:,:].values-tab_e_ind.iloc[:-1,:].values
diff_19 = tab_e_ind.iloc[:,:].values-av_19

tab_e_ind_change = pd.DataFrame(diff,columns=tab_e_ind.keys(),index=tab_e_ind.index[1:])
tab_e_ind_change_rel = pd.DataFrame(diff/tab_e_ind.iloc[:-1,:].values,columns=tab_e_ind.keys(),index=tab_e_ind.index[1:])

tab_e_ind_change19 = pd.DataFrame(diff_19,columns=tab_e_ind.keys(),index=tab_e_ind.index[:])
tab_e_ind_change19_rel = pd.DataFrame(diff_19/av_19,columns=tab_e_ind.keys(),index=tab_e_ind.index[:])

tab_e_ind_change19_rel
# Out:
#         agriculture  manufactures, primary  extractive and energy  \
# 2005Q1    -0.041172               0.257779               0.065548
# 2005Q2     0.011949               0.273555               0.082052
# 2005Q3     0.025988               0.272621               0.107412
# 2005Q4     0.064352               0.277069               0.118528
# 2006Q1     0.029275               0.226050               0.120431
# ...             ...                    ...                    ...
# 2021Q4     0.089617              -0.038452               0.023193
# 2022Q1     0.089721              -0.036982              -0.000862
# 2022Q2     0.018484               0.013726               0.038660
# 2022Q3    -0.108081               0.010440               0.034359
# 2022Q4    -0.061330               0.038210               0.016217
#
#         manufactures, secondary  construction  hospitality and sales  \
# 2005Q1                 0.099594      0.917041              -0.224023
# 2005Q2                 0.108256      0.981665              -0.183430
# 2005Q3                 0.140288      1.029179              -0.163393
# 2005Q4                 0.079849      1.049969              -0.163056
# 2006Q1                 0.112064      1.058526              -0.174234
# ...                         ...           ...                    ...
# 2021Q4                -0.019838      0.001760              -0.066078
# 2022Q1                -0.051066      0.020677              -0.074516
# 2022Q2                -0.055082      0.035776              -0.011973
# 2022Q3                -0.006120      0.040459               0.004478
# 2022Q4                -0.006227      0.001089              -0.017469
#
#         Transport, storage and IT.  Financial and prof. serv.  \
# 2005Q1                   -0.364629                  -0.198323
# 2005Q2                   -0.362689                  -0.144728
# 2005Q3                   -0.343434                  -0.139984
# 2005Q4                   -0.352338                  -0.114953
# 2006Q1                   -0.348438                  -0.102127
# ...                            ...                        ...
# 2021Q4                    0.095462                   0.085598
# 2022Q1                    0.112097                   0.056827
# 2022Q2                    0.120406                   0.052527
# 2022Q3                    0.146028                   0.071942
# 2022Q4                    0.156593                   0.071800
#
#         Education and healthcare  Other services
# 2005Q1                 -0.215100        0.017319
# 2005Q2                 -0.203886        0.050601
# 2005Q3                 -0.202408        0.099289
# 2005Q4                 -0.189545        0.062511
# 2006Q1                 -0.183260        0.102258
# ...                          ...             ...
# 2021Q4                  0.082063       -0.102939
# 2022Q1                  0.081956       -0.061978
# 2022Q2                  0.093828       -0.035341
# 2022Q3                  0.090265       -0.032557
# 2022Q4                  0.107902       -0.054975
#
# [72 rows x 10 columns]

# %% [markdown]
# ## Reading the regression table
#
# From latex to pandas

# %%
from astropy.table import Table
tab = Table.read('./results/qtreg_ind_3540_10.tex').to_pandas()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 2
#       1 from astropy.table import Table
# ----> 2 tab = Table.read('./results/qtreg_ind_3540_10.tex').to_pandas()
#
# File ~\anaconda\lib\site-packages\astropy\table\connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      59 units = kwargs.pop("units", None)
#      60 descriptions = kwargs.pop("descriptions", None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#      69 if cls is not out.__class__:
#
# File ~\anaconda\lib\site-packages\astropy\io\registry\core.py:203, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     199 try:
#     200     ctx = get_readable_fileobj(
#     201         args[0], encoding="binary", cache=cache
#     202     )
# --> 203     fileobj = ctx.__enter__()
#     204 except OSError:
#     205     raise
#
# File ~\anaconda\lib\contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~\anaconda\lib\site-packages\astropy\utils\data.py:353, in get_readable_fileobj(name_or_obj, encoding, cache, show_progress, remote_timeout, sources, http_headers, use_fsspec, fsspec_kwargs, close_files)
#     344 if is_url:
#     345     name_or_obj = download_file(
#     346         name_or_obj,
#     347         cache=cache,
#    (...)
#     351         http_headers=http_headers,
#     352     )
# --> 353 fileobj = io.FileIO(name_or_obj, "r")
#     354 if is_url and not cache:
#     355     delete_fds.append(fileobj)
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/qtreg_ind_3540_10.tex'

# %%
tab = tab.set_index('col0')
tab
# Out:
#                          Parents, 25th pctl Parents, 50th pctl  \
# col0
# $t$                          $-0.009^{***}$     $-0.004^{***}$
# NaN                                (0.0006)           (0.0015)
# $t$ x female                  $0.014^{***}$      $0.051^{***}$
# NaN                                (0.0010)           (0.0022)
# unemployment rate x male      $0.027^{***}$      $0.039^{***}$
# ...                                     ...                ...
# NaN                                (0.3206)           (0.5239)
# $\beta_0$                        $-1.057^*$     $-3.058^{***}$
# NaN                                (0.5975)           (0.8218)
# N                                   413,784            413,784
# Pseudo $R^2$                         0.0354             0.0468
#
#                          Parents, 75th pctl
# col0
# $t$                                 $0.002$
# NaN                                (0.0016)
# $t$ x female                  $0.033^{***}$
# NaN                                (0.0021)
# unemployment rate x male           $-0.003$
# ...                                     ...
# NaN                                (0.3636)
# $\beta_0$                          $-1.068$
# NaN                                (0.8263)
# N                                   413,784
# Pseudo $R^2$                         0.0279
#
# [168 rows x 3 columns]

# %%
IoI = []
for idx in tab.index:
    if str(idx)[:10]=="$\delta_{2":
        if idx.split(' x ')[-1]=='female':
            IoI.append(idx)
tab_dummies_f=tab.loc[IoI,:].copy()
tab_dummies_f
# Out:
#                                                    Parents, 25th pctl  \
# col0
# $\delta_{2020}$ x Agriculture x female                 $-0.461^{***}$
# $\delta_{2020}$ x Manifactures prim. x female               $0.465^*$
# $\delta_{2020}$ x Extractive + energy x female               $-0.016$
# $\delta_{2020}$ x manifuctures sec. x female            $-1.089^{**}$
# $\delta_{2020}$ x Construction x female                      $-0.599$
# $\delta_{2020}$ x Hospitality + Sales x female               $-0.099$
# $\delta_{2020}$ x Transport, Storage + IT x female     $-1.224^{***}$
# $\delta_{2020}$ x Financial + porf. serv. x female     $-0.867^{***}$
# $\delta_{2020}$ x Education + Health x female           $-0.962^{**}$
# $\delta_{2020}$ x Other Services x female              $-1.443^{***}$
# $\delta_{2021}$ x Agriculture x female                 $-0.637^{***}$
# $\delta_{2021}$ x Manifactures prim. x female                $-0.533$
# $\delta_{2021}$ x Extractive + energy x female               $-0.405$
# $\delta_{2021}$ x manifuctures sec. x female           $-1.266^{***}$
# $\delta_{2021}$ x Construction x female                      $-0.479$
# $\delta_{2021}$ x Hospitality + Sales x female         $-0.843^{***}$
# $\delta_{2021}$ x Transport, Storage + IT x female     $-0.868^{***}$
# $\delta_{2021}$ x Financial + porf. serv. x female     $-1.226^{***}$
# $\delta_{2021}$ x Education + Health x female                $-0.195$
# $\delta_{2022}$ x Manifactures prim. x female           $-0.583^{**}$
# $\delta_{2022}$ x Extractive + energy x female               $-0.369$
# $\delta_{2022}$ x manifuctures sec. x female            $-1.442^{**}$
# $\delta_{2022}$ x Construction x female                $-1.895^{***}$
# $\delta_{2022}$ x Hospitality + Sales x female               $-0.259$
# $\delta_{2022}$ x Transport, Storage + IT x female     $-1.017^{***}$
# $\delta_{2022}$ x Financial + porf. serv. x female     $-1.287^{***}$
# $\delta_{2022}$ x Education + Health x female          $-1.230^{***}$
# $\delta_{2022}$ x Other Services x female               $0.942^{***}$
#
#                                                    Parents, 50th pctl  \
# col0
# $\delta_{2020}$ x Agriculture x female                  $-1.330^{**}$
# $\delta_{2020}$ x Manifactures prim. x female                 $0.367$
# $\delta_{2020}$ x Extractive + energy x female                $0.504$
# $\delta_{2020}$ x manifuctures sec. x female                 $-1.743$
# $\delta_{2020}$ x Construction x female                $-3.122^{***}$
# $\delta_{2020}$ x Hospitality + Sales x female               $-0.376$
# $\delta_{2020}$ x Transport, Storage + IT x female           $-0.462$
# $\delta_{2020}$ x Financial + porf. serv. x female           $-1.064$
# $\delta_{2020}$ x Education + Health x female          $-2.408^{***}$
# $\delta_{2020}$ x Other Services x female              $-1.915^{***}$
# $\delta_{2021}$ x Agriculture x female                 $-2.408^{***}$
# $\delta_{2021}$ x Manifactures prim. x female          $-2.539^{***}$
# $\delta_{2021}$ x Extractive + energy x female               $-0.554$
# $\delta_{2021}$ x manifuctures sec. x female           $-3.085^{***}$
# $\delta_{2021}$ x Construction x female                $-3.062^{***}$
# $\delta_{2021}$ x Hospitality + Sales x female         $-1.531^{***}$
# $\delta_{2021}$ x Transport, Storage + IT x female            $0.250$
# $\delta_{2021}$ x Financial + porf. serv. x female     $-2.761^{***}$
# $\delta_{2021}$ x Education + Health x female          $-2.965^{***}$
# $\delta_{2022}$ x Manifactures prim. x female          $-3.392^{***}$
# $\delta_{2022}$ x Extractive + energy x female         $-3.522^{***}$
# $\delta_{2022}$ x manifuctures sec. x female           $-2.859^{***}$
# $\delta_{2022}$ x Construction x female                $-3.506^{***}$
# $\delta_{2022}$ x Hospitality + Sales x female         $-3.098^{***}$
# $\delta_{2022}$ x Transport, Storage + IT x female     $-1.786^{***}$
# $\delta_{2022}$ x Financial + porf. serv. x female     $-2.422^{***}$
# $\delta_{2022}$ x Education + Health x female          $-3.138^{***}$
# $\delta_{2022}$ x Other Services x female              $-3.457^{***}$
#
#                                                    Parents, 75th pctl
# col0
# $\delta_{2020}$ x Agriculture x female                       $-1.066$
# $\delta_{2020}$ x Manifactures prim. x female                 $0.128$
# $\delta_{2020}$ x Extractive + energy x female                $0.908$
# $\delta_{2020}$ x manifuctures sec. x female                  $0.574$
# $\delta_{2020}$ x Construction x female                       $0.165$
# $\delta_{2020}$ x Hospitality + Sales x female                $1.359$
# $\delta_{2020}$ x Transport, Storage + IT x female           $-0.209$
# $\delta_{2020}$ x Financial + porf. serv. x female           $-0.505$
# $\delta_{2020}$ x Education + Health x female           $-0.450^{**}$
# $\delta_{2020}$ x Other Services x female                     $0.308$
# $\delta_{2021}$ x Agriculture x female                       $-1.690$
# $\delta_{2021}$ x Manifactures prim. x female          $-3.830^{***}$
# $\delta_{2021}$ x Extractive + energy x female               $-0.663$
# $\delta_{2021}$ x manifuctures sec. x female                 $-0.858$
# $\delta_{2021}$ x Construction x female                    $-2.946^*$
# $\delta_{2021}$ x Hospitality + Sales x female               $-0.353$
# $\delta_{2021}$ x Transport, Storage + IT x female           $-0.434$
# $\delta_{2021}$ x Financial + porf. serv. x female     $-1.942^{***}$
# $\delta_{2021}$ x Education + Health x female                $-0.205$
# $\delta_{2022}$ x Manifactures prim. x female                $-1.333$
# $\delta_{2022}$ x Extractive + energy x female         $-3.248^{***}$
# $\delta_{2022}$ x manifuctures sec. x female           $-2.149^{***}$
# $\delta_{2022}$ x Construction x female                      $-1.294$
# $\delta_{2022}$ x Hospitality + Sales x female                $0.291$
# $\delta_{2022}$ x Transport, Storage + IT x female            $0.020$
# $\delta_{2022}$ x Financial + porf. serv. x female         $-1.681^*$
# $\delta_{2022}$ x Education + Health x female              $-1.028^*$
# $\delta_{2022}$ x Other Services x female              $-0.999^{***}$

# %%
IoI_base = []
for ind in IoI:
    IoI_base.append(ind.replace(' x female',''))
tab_dummies=tab.loc[IoI_base,:].copy()
tab_dummies
# Out:
#                                           Parents, 25th pctl  \
# col0
# $\delta_{2020}$ x Agriculture                  $-0.463^{**}$
# $\delta_{2020}$ x Manifactures prim.               $0.261^*$
# $\delta_{2020}$ x Extractive + energy                $0.107$
# $\delta_{2020}$ x manifuctures sec.            $0.668^{***}$
# $\delta_{2020}$ x Construction                       $0.158$
# $\delta_{2020}$ x Hospitality + Sales                $0.167$
# $\delta_{2020}$ x Transport, Storage + IT      $0.450^{***}$
# $\delta_{2020}$ x Financial + porf. serv.            $0.427$
# $\delta_{2020}$ x Education + Health           $1.953^{***}$
# $\delta_{2020}$ x Other Services               $0.591^{***}$
# $\delta_{2021}$ x Agriculture                        $0.482$
# $\delta_{2021}$ x Manifactures prim.                $-0.087$
# $\delta_{2021}$ x Extractive + energy                $0.130$
# $\delta_{2021}$ x manifuctures sec.            $0.863^{***}$
# $\delta_{2021}$ x Construction                 $0.915^{***}$
# $\delta_{2021}$ x Hospitality + Sales               $-0.175$
# $\delta_{2021}$ x Transport, Storage + IT          $0.502^*$
# $\delta_{2021}$ x Financial + porf. serv.           $-0.441$
# $\delta_{2021}$ x Education + Health            $1.060^{**}$
# $\delta_{2022}$ x Manifactures prim.                 $0.106$
# $\delta_{2022}$ x Extractive + energy               $-0.081$
# $\delta_{2022}$ x manifuctures sec.            $0.895^{***}$
# $\delta_{2022}$ x Construction                 $1.076^{***}$
# $\delta_{2022}$ x Hospitality + Sales          $1.227^{***}$
# $\delta_{2022}$ x Transport, Storage + IT         $-0.201^*$
# $\delta_{2022}$ x Financial + porf. serv.            $0.202$
# $\delta_{2022}$ x Education + Health          $-1.441^{***}$
# $\delta_{2022}$ x Other Services                $1.186^{**}$
#
#                                           Parents, 50th pctl  \
# col0
# $\delta_{2020}$ x Agriculture                 $-1.549^{***}$
# $\delta_{2020}$ x Manifactures prim.          $-1.080^{***}$
# $\delta_{2020}$ x Extractive + energy               $-0.520$
# $\delta_{2020}$ x manifuctures sec.            $0.783^{***}$
# $\delta_{2020}$ x Construction                $-1.062^{***}$
# $\delta_{2020}$ x Hospitality + Sales               $-0.930$
# $\delta_{2020}$ x Transport, Storage + IT            $0.818$
# $\delta_{2020}$ x Financial + porf. serv.      $1.550^{***}$
# $\delta_{2020}$ x Education + Health               $1.186^*$
# $\delta_{2020}$ x Other Services                     $0.410$
# $\delta_{2021}$ x Agriculture                       $-0.136$
# $\delta_{2021}$ x Manifactures prim.          $-1.092^{***}$
# $\delta_{2021}$ x Extractive + energy             $-1.063^*$
# $\delta_{2021}$ x manifuctures sec.            $0.853^{***}$
# $\delta_{2021}$ x Construction                    $-0.523^*$
# $\delta_{2021}$ x Hospitality + Sales         $-1.327^{***}$
# $\delta_{2021}$ x Transport, Storage + IT            $0.109$
# $\delta_{2021}$ x Financial + porf. serv.      $1.516^{***}$
# $\delta_{2021}$ x Education + Health           $2.069^{***}$
# $\delta_{2022}$ x Manifactures prim.                 $0.157$
# $\delta_{2022}$ x Extractive + energy               $-0.352$
# $\delta_{2022}$ x manifuctures sec.            $-0.822^{**}$
# $\delta_{2022}$ x Construction                 $1.426^{***}$
# $\delta_{2022}$ x Hospitality + Sales                $0.166$
# $\delta_{2022}$ x Transport, Storage + IT     $-1.034^{***}$
# $\delta_{2022}$ x Financial + porf. serv.            $0.100$
# $\delta_{2022}$ x Education + Health                 $0.715$
# $\delta_{2022}$ x Other Services                $1.768^{**}$
#
#                                           Parents, 75th pctl
# col0
# $\delta_{2020}$ x Agriculture                       $-0.361$
# $\delta_{2020}$ x Manifactures prim.                 $0.039$
# $\delta_{2020}$ x Extractive + energy                $0.052$
# $\delta_{2020}$ x manifuctures sec.            $2.148^{***}$
# $\delta_{2020}$ x Construction                    $-0.764^*$
# $\delta_{2020}$ x Hospitality + Sales                $0.540$
# $\delta_{2020}$ x Transport, Storage + IT      $1.059^{***}$
# $\delta_{2020}$ x Financial + porf. serv.          $0.329^*$
# $\delta_{2020}$ x Education + Health                 $0.733$
# $\delta_{2020}$ x Other Services                     $0.769$
# $\delta_{2021}$ x Agriculture                        $0.134$
# $\delta_{2021}$ x Manifactures prim.                 $0.530$
# $\delta_{2021}$ x Extractive + energy                $0.212$
# $\delta_{2021}$ x manifuctures sec.            $3.134^{***}$
# $\delta_{2021}$ x Construction                      $-0.362$
# $\delta_{2021}$ x Hospitality + Sales                $0.852$
# $\delta_{2021}$ x Transport, Storage + IT      $1.640^{***}$
# $\delta_{2021}$ x Financial + porf. serv.          $0.243^*$
# $\delta_{2021}$ x Education + Health                 $0.559$
# $\delta_{2022}$ x Manifactures prim.                 $0.617$
# $\delta_{2022}$ x Extractive + energy                $0.592$
# $\delta_{2022}$ x manifuctures sec.                 $-0.223$
# $\delta_{2022}$ x Construction                       $0.120$
# $\delta_{2022}$ x Hospitality + Sales               $-0.045$
# $\delta_{2022}$ x Transport, Storage + IT           $-0.158$
# $\delta_{2022}$ x Financial + porf. serv.           $-0.218$
# $\delta_{2022}$ x Education + Health                 $0.392$
# $\delta_{2022}$ x Other Services                     $0.540$

# %%
def stars_to_sig(thing):
    if thing[-5:] == '***}$':         
        res = 0.01
    elif thing[-5:] == '{**}$':
        res = 0.05
    elif thing[-3:] == '^*$':
        res = 0.1
    else:
        res = 1.0
    return res

# %%
pctiles = [25,50,75]

for p in pctiles:
    sig_list = []
    sig_list2 = []
    for name in IoI:
        thing = tab_dummies_f.loc[name,'Parents, {}th pctl'.format(p)]
        sig_list.append(stars_to_sig(thing))
    for name in IoI_base:
        thing2 = tab_dummies.loc[name,'Parents, {}th pctl'.format(p)]
        sig_list2.append(stars_to_sig(thing2))
    tab_dummies_f['sig {}'.format(p)] = np.array(sig_list)
    tab_dummies['sig {}'.format(p)] = np.array(sig_list2)

# %%
for p in pctiles:
    num_list,num_list2 = [],[]
    for name in IoI:
        thing = tab_dummies_f.loc[name,'Parents, {}th pctl'.format(p)]
        thing = thing.replace('*','').replace('{','').replace('}','').replace('$','').replace('^','')
        num_list.append(thing)
    for name in IoI_base:
        thing2 = tab_dummies.loc[name,'Parents, {}th pctl'.format(p)]
        thing2 = thing2.replace('*','').replace('{','').replace('}','').replace('$','').replace('^','')
        num_list2.append(thing2)
    tab_dummies_f.loc[:,'Parents, {}th pctl'.format(p)] = num_list
    tab_dummies.loc[:,'Parents, {}th pctl'.format(p)] = num_list2

# %%
indust_list = []
for name in IoI:
    indust_list.append(name.split(' x ')[1])
dic_ind_translate = dict(zip(indust_list[:10],industry_dict.values()))

all_ind_dums = []
all_year_dums = []
for ind in tab_dummies_f.index:
    all_ind_dums.append(dic_ind_translate[ind.split(' x ')[1]])
    all_year_dums.append(int(ind.split(' x ')[0].replace('$\\delta_{','').replace("}$","")))
tab_dummies_f['year'] = all_year_dums
tab_dummies_f['ind'] = all_ind_dums

all_ind_dums2 = []
all_year_dums2 = []
for ind in tab_dummies.index:
    all_ind_dums2.append(dic_ind_translate[ind.split(' x ')[1]])
    all_year_dums2.append(int(ind.split(' x ')[0].replace('$\\delta_{','').replace("}$","")))
tab_dummies['year'] = all_year_dums2
tab_dummies['ind'] = all_ind_dums2

# %%
tab_dummies_f = tab_dummies_f.set_index(['year','ind'])
tab_dummies_f.head()
# Out:
#                              Parents, 25th pctl Parents, 50th pctl  \
# year ind
# 2020 agriculture                         -0.461             -1.330
#      manufactures, primary                0.465              0.367
#      extractive and energy               -0.016              0.504
#      manufactures, secondary             -1.089             -1.743
#      construction                        -0.599             -3.122
#
#                              Parents, 75th pctl  sig 25  sig 50  sig 75
# year ind
# 2020 agriculture                         -1.066    0.01    0.05     1.0
#      manufactures, primary                0.128    0.10    1.00     1.0
#      extractive and energy                0.908    1.00    1.00     1.0
#      manufactures, secondary              0.574    0.05    1.00     1.0
#      construction                         0.165    1.00    0.01     1.0

# %%
tab_dummies = tab_dummies.set_index(['year','ind'])
tab_dummies.head()
# Out:
#                              Parents, 25th pctl Parents, 50th pctl  \
# year ind
# 2020 agriculture                         -0.463             -1.549
#      manufactures, primary                0.261             -1.080
#      extractive and energy                0.107             -0.520
#      manufactures, secondary              0.668              0.783
#      construction                         0.158             -1.062
#
#                              Parents, 75th pctl  sig 25  sig 50  sig 75
# year ind
# 2020 agriculture                         -0.361    0.05    0.01    1.00
#      manufactures, primary                0.039    0.10    0.01    1.00
#      extractive and energy                0.052    1.00    1.00    1.00
#      manufactures, secondary              2.148    0.01    0.01    0.01
#      construction                        -0.764    1.00    0.01    0.10

# %%
tab_e_ind_change19_rel_y.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-0279fe3c2080> in <module>
# ----> 1 tab_e_ind_change19_rel_y.head()
#
# NameError: name 'tab_e_ind_change19_rel_y' is not defined

# %%
tab_dummies_f.loc[2021]
# Out:
#                            Parents, 25th pctl Parents, 50th pctl  \
# ind
# agriculture                            -0.637             -2.408
# manufactures, primary                  -0.533             -2.539
# extractive and energy                  -0.405             -0.554
# manufactures, secondary                -1.266             -3.085
# construction                           -0.479             -3.062
# hospitality and sales                  -0.843             -1.531
# Transport, storage and IT.             -0.868              0.250
# Financial and prof. serv.              -1.226             -2.761
# Education and healthcare               -0.195             -2.965
#
#                            Parents, 75th pctl  sig 25  sig 50  sig 75
# ind
# agriculture                            -1.690    0.01    0.01    1.00
# manufactures, primary                  -3.830    1.00    0.01    0.01
# extractive and energy                  -0.663    1.00    1.00    1.00
# manufactures, secondary                -0.858    0.01    0.01    1.00
# construction                           -2.946    1.00    0.01    0.10
# hospitality and sales                  -0.353    0.01    0.01    1.00
# Transport, storage and IT.             -0.434    0.01    1.00    1.00
# Financial and prof. serv.              -1.942    0.01    0.01    0.01
# Education and healthcare               -0.205    1.00    0.01    1.00

# %%
def significance_stars(sig):
    if sig <=0.01:
        sigg = '$^{***}$'
    elif sig <=0.05:
        sigg = '$^{**}$'
    elif sig <=0.1:
        sigg = '$^{*}$'
    else:
        sigg = ''
    return sigg

# %%
colors = sn.color_palette('tab10',10)
ind_acronyms = ['AGRI','MAN1','EXTR','MAN2','CONS','HOSP','TSIT','FINP','EDHC','OTHS']
color_dict = dict(zip(industry_dict.values(),colors))
size_dict = dict(zip(industry_dict.values(),1000*av_19/np.sum(av_19)))
acro_dict = dict(zip(industry_dict.values(),ind_acronyms))
plt.figure(figsize=(15,4))
for i,year in enumerate([2020,2021,2022]):
    plt.subplot(131+i)
    plt.title(year,fontsize=16)
    for ind in tab_dummies_f.loc[year,:].index:
        sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig 25'])
        plt.scatter(tab_e_ind_change19_rel_y.loc[year,ind],float(tab_dummies_f.loc[(year,ind),'Parents, 25th pctl']),
                    color=color_dict[ind],s=size_dict[ind],label=acro_dict[ind]+": "+ind)
        plt.annotate(acro_dict[ind]+sig,
                     xy=(tab_e_ind_change19_rel_y.loc[year,ind],float(tab_dummies_f.loc[(year,ind),'Parents, 25th pctl'])-0.05))
    plt.ylim(-2,1)
    plt.xlim(-0.1,0.2)
    plt.axvline(c='k',lw=1)
    plt.axhline(c='k',lw=1)
    if year == 2020:
        plt.legend(ncol=3,fontsize=12,bbox_to_anchor=(3.,-0.15))
# plt.tight_layout()
plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(15,15))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies_f.loc[year,:].index:
            sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(tab_e_ind_change19_rel_y.loc[year,ind],
                        float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,xy=(tab_e_ind_change19_rel_y.loc[year,ind],
                                                float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
        plt.ylim(-4,2)
        plt.xlim(-0.1,0.2)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        if xx >336:
            plt.xlabel(r'$\Delta$ Employment$_{2019}$')
plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.savefig('./plots_stocks/scatter_indE_mother_penalty.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(16,17))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies_f.loc[year,:].index:
            sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
                        float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,xy=(float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
                                                 float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
        plt.ylim(-4,4)
        plt.xlim(-4,4)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        plt.xlabel(r"$\delta_{"+str(year)+"}$")
#         if xx >336:
        plt.ylabel(r"$\delta_{"+str(year)+"}$ x female")
# plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.tight_layout()
plt.savefig('./plots_stocks/scatter_indE_mother_father_dummies.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(16,17))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies_f.loc[year,:].index:
            sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            base_point = float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)])
            plt.scatter(base_point,base_point+float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
                        color=color_dict[ind],s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,
                         xy=(base_point,base_point+float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
            plt.plot([-4,3],[-4,3], color='grey',lw=1)
        plt.ylim(-4,3)
        plt.xlim(-4,3)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        plt.xlabel(r"$\delta_{"+str(year)+"}$")
#         if xx >336:
        plt.ylabel(r"$\delta_{"+str(year)+"}$ + "+r"$\delta_{"+str(year)+"}$ x female")
# plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.tight_layout()
plt.savefig('./plots_stocks/scatter_indE_mother_father_dummies45.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(15,15))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies.loc[year,:].index:
            sig = significance_stars(tab_dummies.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(tab_e_ind_change19_rel_y.loc[year,ind],
                        float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,xy=(tab_e_ind_change19_rel_y.loc[year,ind],
                                                float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
        plt.ylim(-2,4)
        plt.xlim(-0.1,0.2)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        if xx >336:
            plt.xlabel(r'$\Delta$ Employment$_{2019}$')
plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.savefig('./plots_stocks/scatter_indE.pdf',format='pdf',bbox_inches='tight')
plt.show()
