# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.optimize import fsolve

#from f_detrend import detrend_fuction

sn.set_style('whitegrid')
# %matplotlib inline

# %%
# Expanded and modivfied version (first column now string)
def read_table(filename,keyword='ciclo',rescale=1,ncols=5,start=2):
    t0 = start
    t1 = ncols+start
    results_follow = 0
    row_names = []
    table_raw = np.empty(t1-t0)
    f = open(filename,'r')
    for line in f:
        words = line.split()
        if len(words)>1 and words[0] == keyword:
            results_follow=1
            colnames = words[t0:t1]
        elif len(words)>1 and words[0] == "Total":
            break
        elif len(words)>1 and results_follow==1:
            row_names.append(words[0])
            buff_v = []
            for w in words[t0:t1]: 
                w = w.replace(",","")
                buff_v.append(w)
            table_raw = np.vstack((table_raw,np.array(buff_v,dtype=float)/rescale))
    table_raw = table_raw[1:,:]
    return pd.DataFrame(table_raw, columns=colnames,index=np.array(row_names))

# %%
dates = []
for year in range(1987,2023):
    for quarter in range(1,5):
        dates.append(str(year)+"Q"+str(quarter))
dates = dates[1:]

t0 = 59
T = len(dates)
date_dict = dict(zip(range(t0,T+t0),dates))
date_dict_reverse = dict(zip(dates,range(0,T)))
date_dict_reverse_ciclo = dict(zip(dates,range(t0,T+t0)))

# %% [markdown]
# # Parent Age 35-40

# %% [markdown]
#  ## Children Age <5

# %%
coefs_par_a3045_p5 = []
coefs_mar_a3045_p5 = []
coefs_parxmar_a3045_p5 = []
coefs_div_a3045_p5 = []
bounds_par_a3045_p5 = []
bounds_mar_a3045_p5 = []
bounds_parxmar_a3045_p5 = []
bounds_div_a3045_p5 = []
qs = []
cc = 130
f = open('./regtabs/prob_perm_stocks_w_age3540_parent_5_cohab.log','r')
for line in f:
    words = line.split()
    #print(words)
    if  len(words)>1 and words[0]=='permanent' and words[1]=='|':
        #indx_if = words.index("if")
        #ciclo = int(words[indx_if+1][7:10])
        ciclo = cc
        qs.append(date_dict[ciclo])
        cc +=1
    if len(words)>0 and 'parent_5'==words[0]:
        coefs_par_a3045_p5.append(float(words[2]))
        bounds_par_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_mar_a3045_p5.append(float(words[2]))
        bounds_mar_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_5'==words[0]:
        coefs_parxmar_a3045_p5.append(float(words[2]))
        bounds_parxmar_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_div_a3045_p5.append(float(words[2]))
        bounds_div_a3045_p5.append((float(words[-2]),float(words[-1])))
bounds_par_a3045_p5 = np.array(bounds_par_a3045_p5)
coefs_par_a3045_p5 = np.array(coefs_par_a3045_p5)
bounds_mar_a3045_p5 = np.array(bounds_mar_a3045_p5)
coefs_mar_a3045_p5 = np.array(coefs_mar_a3045_p5)
bounds_parxmar_a3045_p5 = np.array(bounds_parxmar_a3045_p5)
coefs_parxmar_a3045_p5 = np.array(coefs_parxmar_a3045_p5)
bounds_div_a3045_p5 = np.array(bounds_div_a3045_p5)
coefs_div_a3045_p5 = np.array(coefs_div_a3045_p5)

# %%
coefs_m_par_a3045_p5 = []
coefs_m_mar_a3045_p5 = []
coefs_m_parxmar_a3045_p5 = []
coefs_m_div_a3045_p5 = []
bounds_m_par_a3045_p5 = []
bounds_m_mar_a3045_p5 = []
bounds_m_parxmar_a3045_p5 = []
bounds_m_div_a3045_p5 = []
f = open('./regtabs/prob_perm_stocks_m_age3540_parent_5_cohab.log','r')
for line in f:
    words = line.split()
    print(words)
    if len(words)>0 and 'parent_5'==words[0]:        
        coefs_m_par_a3045_p5.append(float(words[2]))
        bounds_m_par_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_m_mar_a3045_p5.append(float(words[2]))
        bounds_m_mar_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_5'==words[0]:
        coefs_m_parxmar_a3045_p5.append(float(words[2]))
        bounds_m_parxmar_a3045_p5.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_m_div_a3045_p5.append(float(words[2]))
        bounds_m_div_a3045_p5.append((float(words[-2]),float(words[-1])))
bounds_m_par_a3045_p5 = np.array(bounds_m_par_a3045_p5)
coefs_m_par_a3045_p5 = np.array(coefs_m_par_a3045_p5)
bounds_m_mar_a3045_p5 = np.array(bounds_m_mar_a3045_p5)
coefs_m_mar_a3045_p5 = np.array(coefs_m_mar_a3045_p5)
bounds_m_parxmar_a3045_p5 = np.array(bounds_m_parxmar_a3045_p5)
coefs_m_parxmar_a3045_p5 = np.array(coefs_m_parxmar_a3045_p5)
bounds_m_div_a3045_p5 = np.array(bounds_m_div_a3045_p5)
coefs_m_div_a3045_p5 = np.array(coefs_m_div_a3045_p5)
# Out:
# ['note:', 'erte', '!=', '0', 'predicts', 'failure', 'perfectly;']
# ['erte', 'omitted', 'and', '3', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,468']
# ['Wald', 'chi2(21)', '=', '343.90']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-632022.21', 'Pseudo', 'R2', '=', '0.1413']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '8.778517', '3.301375', '5.78', '0.000', '4.20055', '18.34578']
# ['extractive', 'and', 'energy.', '|', '11.9408', '4.277077', '6.92', '0.000', '5.917539', '24.09492']
# ['manufactures,', 'sec.', '|', '8.283527', '3.119982', '5.61', '0.000', '3.959233', '17.33084']
# ['construction', '|', '2.104289', '.6999709', '2.24', '0.025', '1.096381', '4.03877']
# ['hospitality', 'and', 'sales', '|', '3.61854', '1.183336', '3.93', '0.000', '1.906221', '6.868999']
# ['Transport,', 'storage', 'and', 'IT.', '|', '4.108577', '1.439991', '4.03', '0.000', '2.067087', '8.166277']
# ['Financial', 'and', 'prof.', 'serv.', '|', '4.436002', '1.528896', '4.32', '0.000', '2.257458', '8.716932']
# ['Education', 'and', 'healthcare', '|', '2.111433', '.8308256', '1.90', '0.058', '.9764254', '4.565788']
# ['Other', 'services', '|', '4.179612', '1.659384', '3.60', '0.000', '1.919522', '9.100787']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '2.211474', '.5347303', '3.28', '0.001', '1.376774', '3.552227']
# ['white', 'collar', '-', 'tech.', 'suport', '|',

# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.1306997', '.0465324', '-5.72', '0.000', '.0650467', '.2626178']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'success', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,382']
# ['Wald', 'chi2(21)', '=', '384.96']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-639658.12', 'Pseudo', 'R2', '=', '0.1525']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '5.539555', '2.05568', '4.61', '0.000', '2.676711', '11.46432']
# ['extractive', 'and', 'energy.', '|', '6.121457', '1.973576', '5.62', '0.000', '3.254054', '11.51555']
# ['manufactures,', 'sec.', '|', '6.195172', '2.101341', '5.38', '0.000', '3.186649', '12.04405']
# ['construction', '|', '1.108355', '.3282526', '0.35', '0.728', '.6202764', '1.980489']
# ['hospitality', 'and', 'sales', '|', '1.836765', '.5420433', '2.06', '0.039', '1.030048', '3.275289']
# ['Transport,', 'storage', 'and', 'IT.', '|', '2.411211', '.7910534', '2.68', '0.007', '1.26759', '4.586607']
# ['Financial', 'and', 'prof.', 'serv.', '|', '2.795333', '.8814261', '3.26', '0.001', '1.506719', '5.186029']
# ['Education', 'and', 'healthcare', '|', '1.677303', '.6459179', '1.34', '0.179', '.7885325', '3.567824']
# ['Other', 'services', '|', '1.253654', '.4766963', '0.59', '0.552', '.5949936', '2.641455']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '2.767149', '.6338646', '4.44', '0.000', '1.76624', '4.335262']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '6.796357', '1.525265', '8.54', '0.000', '4.377703', '10.5513']
# ['white', 'collar', '-', 'other', '|', '10.12635', '3.330805', '7.04', '0.000', '5.314615', '19.29452']
# ['blue', 'collar', '-', 'services', '|', '8.542931', '2.055388', '8.92', '0.000', '5.331039', '13.68995']
# ['blue', 'collar', '-', 'agriculture', '|', '1.195743', '.518905', '0.41', '0.680', '.5107991', '2.799146']
# ['blue', 'collar', '-', 'artisans', '|', '3.206034', '.6535298', '5.72', '0.000', '2.150087', '4.780576']
# ['blue', 'collar', '-', 'equip.', '|', '3.320103', '.7146042', '5.58', '0.000', '2.177422', '5.062446']
# ['unskilled', '|', '2.791743', '.6532932', '4.39', '0.000', '1.764763', '4.416358']
# ['|']
# ['public_servant', '|', '3.840813', '1.095433', '4.72', '0.000', '2.196105', '6.717277']
# ['parent_15', '|', '1.040612', '.1384362', '0.30', '0.765', '.8017714', '1.350601']
# ['part_time', '|', '.3747345', '.1198961', '-3.07', '0.002', '.2001623', '.7015605']
# ['college', '|', '1.563153', '.2103005', '3.32', '0.001', '1.200837', '2.034786']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.1547605', '.0540809', '-5.34', '0.000', '.0780204', '.3069811']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', 'omitted', 'because', 'of', 'collinearity.']
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,371']
# ['Wald', 'chi2(21)', '=', '401.83']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-653784.97', 'Pseudo', 'R2', '=', '0.1503']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '5.167826', '2.231281', '3.80', '0.000', '2.217123', '12.04553']
# ['extractive', 'and', 'energy.', '|', '7.676113', '3.250184', '4.81', '0.000', '3.347569', '17.60164']
# ['manufactures,', 'sec.', '|', '6.201062', '2.708692', '4.18', '0.000', '2.634219', '14.59756']
# ['construction', '|', '1.195501', '.482804', '0.44', '0.658', '.5417406', '2.638204']
# ['hospitality', 'and', 'sales', '|', '2.246524', '.869595', '2.09', '0.037', '1.05202', '4.797314']
# ['Transport,', 'storage', 'and', 'IT.', '|', '3.035491', '1.24681', '2.70', '0.007', '1.357072', '6.789768']
# ['Financial', 'and', 'prof.', 'serv.', '|', '2.80278', '1.131663', '2.55', '0.011', '1.270293', '6.184062']
# ['Education', 'and', 'healthcare', '|', '2.037758', '.9102147', '1.59', '0.111', '.8490685', '4.890606']
# ['Other', 'services', '|', '2.395186', '1.047969', '2.00', '0.046', '1.016043', '5.646333']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '3.321895', '.7831223', '5.09', '0.000', '2.092757', '5.272942']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '7.364305', '1.562879', '9.41', '0.000', '4.858328', '11.16289']
# ['white', 'collar', '-', 'other', '|', '12.17309', '3.97659', '7.65', '0.000', '6.417095', '23.09209']
# ['blue', 'collar', '-', 'services', '|', '9.412936', '2.223359', '9.49', '0.000', '5.924738', '14.95482']
# ['blue', 'collar', '-', 'agriculture', '|', '2.382435', '1.08192', '1.91', '0.056', '.9782959', '5.801921']
# ['blue', 'collar', '-', 'artisans', '|', '3.407818', '.697695', '5.99', '0.000', '2.281428', '5.090331']
# ['blue', 'collar', '-', 'equip.', '|', '4.054369', '.8626276', '6.58', '0.000', '2.671883', '6.152181']
# ['unskilled', '|', '3.499163', '.8520273', '5.14', '0.000', '2.171207', '5.639326']
# ['|']
# ['public_servant', '|', '3.625127', '.9325521', '5.01', '0.000', '2.189547', '6.001945']
# ['parent_15', '|', '1.181162', '.1514735', '1.30', '0.194', '.9186503', '1.518687']
# ['part_time', '|', '.3473579', '.1333757', '-2.75', '0.006', '.163659', '.7372497']
# ['college', '|', '1.596612', '.2227518', '3.35', '0.001', '1.21463', '2.098723']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.1010915', '.0435892', '-5.31', '0.000', '.0434199', '.2353642']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'success', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,494']
# ['Wald', 'chi2(21)', '=', '395.30']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-670816.12', 'Pseudo', 'R2', '=', '0.1407']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '4.403209', '1.428252', '4.57', '0.000', '2.331676', '8.315155']
# ['extractive', 'and', 'energy.', '|', '4.863093', '1.535673', '5.01', '0.000', '2.618901', '9.030379']
# ['manufactures,', 'sec.', '|', '3.47114', '1.174529', '3.68', '0.000', '1.788344', '6.737412']
# ['construction', '|', '.8385931', '.2477984', '-0.60', '0.551', '.4699235', '1.496495']
# ['hospitality', 'and', 'sales', '|', '1.879027', '.5406206', '2.19', '0.028', '1.069131', '3.302439']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.678696', '.5283912', '1.65', '0.100', '.9058269', '3.11099']
# ['Financial', 'and', 'prof.', 'serv.', '|', '2.005664', '.617368', '2.26', '0.024', '1.097104', '3.666642']
# ['Education', 'and', 'healthcare', '|', '1.564375', '.5642582', '1.24', '0.215', '.7714701', '3.172217']
# ['Other', 'services', '|', '2.071001', '.7344918', '2.05', '0.040', '1.033468', '4.150148']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|',

# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '4.769014', '1.488079', '5.01', '0.000', '2.587185', '8.790823']
# ['extractive', 'and', 'energy.', '|', '7.837536', '2.410996', '6.69', '0.000', '4.288757', '14.32279']
# ['manufactures,', 'sec.', '|', '7.301375', '2.345643', '6.19', '0.000', '3.889979', '13.70446']
# ['construction', '|', '1.424263', '.3981332', '1.27', '0.206', '.8234716', '2.463383']
# ['hospitality', 'and', 'sales', '|', '2.694895', '.7527655', '3.55', '0.000', '1.558747', '4.659166']
# ['Transport,', 'storage', 'and', 'IT.', '|', '3.275417', '.9983748', '3.89', '0.000', '1.802242', '5.952782']
# ['Financial', 'and', 'prof.', 'serv.', '|', '3.079543', '.9147709', '3.79', '0.000', '1.720437', '5.51231']
# ['Education', 'and', 'healthcare', '|', '3.016151', '1.05354', '3.16', '0.002', '1.520999', '5.981049']
# ['Other', 'services', '|', '3.357181', '1.280755', '3.17', '0.002', '1.589439', '7.09097']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '2.880826', '.6182436', '4.93', '0.000', '1.891663', '4.387229']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '5.772686', '1.110228', '9.12', '0.000', '3.95978', '8.415594']
# ['white', 'collar', '-', 'other', '|', '7.625189', '2.059602', '7.52', '0.000', '4.490936', '12.94686']
# ['blue', 'collar', '-', 'services', '|', '8.848192', '1.906612', '10.12', '0.000', '5.800125', '13.49807']
# ['blue', 'collar', '-', 'agriculture', '|', '2.934172', '1.168954', '2.70', '0.007', '1.343918', '6.40617']
# ['blue', 'collar', '-', 'artisans', '|', '2.971829', '.4993198', '6.48', '0.000', '2.137996', '4.130862']
# ['blue', 'collar', '-', 'equip.', '|', '3.739405', '.6924694', '7.12', '0.000', '2.60121', '5.375631']
# ['unskilled', '|', '2.052253', '.4303959', '3.43', '0.001', '1.360561', '3.095593']
# ['|']
# ['public_servant', '|', '2.566886', '.6776373', '3.57', '0.000', '1.530017', '4.306425']
# ['parent_15', '|', '1.413743', '.1530903', '3.20', '0.001', '1.143395', '1.748013']
# ['part_time', '|', '.257828', '.1090836', '-3.20', '0.001', '.1125118', '.5908293']
# ['college', '|', '1.729837', '.1971668', '4.81', '0.000', '1.383519', '2.162843']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.0975771', '.0299099', '-7.59', '0.000', '.0535098', '.1779356']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', 'omitted', 'because', 'of', 'collinearity.']
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,806']
# ['Wald', 'chi2(21)', '=', '401.03']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-718855.47', 'Pseudo', 'R2', '=', '0.1360']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '3.586123', '1.246117', '3.68', '0.000', '1.814876', '7.086035']
# ['extractive', 'and', 'energy.', '|', '5.783799', '1.947478', '5.21', '0.000', '2.98953', '11.18983']
# ['manufactures,', 'sec.', '|', '5.535385', '1.900455', '4.98', '0.000', '2.82427', '10.849']
# ['construction', '|', '1.285924', '.4075136', '0.79', '0.427', '.6909817', '2.393117']
# ['hospitality', 'and', 'sales', '|', '2.514597', '.7893853', '2.94', '0.003', '1.359121', '4.652417']
# ['Transport,', 'storage', 'and', 'IT.', '|', '3.322831', '1.099047', '3.63', '0.000', '1.737674', '6.354017']
# ['Financial', 'and', 'prof.', 'serv.', '|', '2.051288', '.6830833', '2.16', '0.031', '1.068008', '3.93984']
# ['Education', 'and', 'healthcare', '|', '2.705653', '1.036773', '2.60', '0.009', '1.276739', '5.733794']
# ['Other', 'services', '|', '1.760262', '.7327081', '1.36', '0.174', '.7785117', '3.980059']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|',
# ['blue', 'collar', '-', 'equip.', '|', '3.426037', '.6204238', '6.80', '0.000', '2.402411', '4.885813']
# ['unskilled', '|', '1.37145', '.2951764', '1.47', '0.142', '.8994484', '2.091142']
# ['|']
# ['public_servant', '|', '4.775672', '1.226456', '6.09', '0.000', '2.886919', '7.900133']
# ['parent_15', '|', '1.148801', '.1234561', '1.29', '0.197', '.9306155', '1.418141']
# ['part_time', '|', '.343881', '.1123651', '-3.27', '0.001', '.181248', '.6524439']
# ['college', '|', '1.998433', '.2370523', '5.84', '0.000', '1.583875', '2.521497']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.2568452', '.1027975', '-3.40', '0.001', '.1172178', '.5627936']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'failure', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,733']
# ['Wald', 'chi2(21)', '=', '383.88']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-722543.88', 'Pseudo', 'R2', '=', '0.1307']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '2.255705', '.9004964', '2.04', '0.042', '1.031515', '4.93275']
# ['extractive', 'and', 'energy.', '|', '3.142781', '1.229134', '2.93', '0.003', '1.460196', '6.76421']
# ['manufactures,', 'sec.', '|', '3.826502', '1.526507', '3.36', '0.001', '1.750782', '8.363188']
# ['construction', '|', '.7972976', '.2975717', '-0.61', '0.544', '.3836458', '1.656954']
# ['hospitality', 'and', 'sales', '|', '1.38765', '.5125785', '0.89', '0.375', '.6727563', '2.862212']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.433107', '.5512784', '0.94', '0.350', '.6742854', '3.045884']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.063027', '.4037194', '0.16', '0.872', '.5049783', '2.237773']
# ['Education', 'and', 'healthcare', '|', '1.20285', '.5016705', '0.44', '0.658', '.5311317', '2.724085']
# ['Other', 'services', '|', '1.006414', '.4565985', '0.01', '0.989', '.4136146', '2.448821']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '2.951293', '.6063719', '5.27', '0.000', '1.972989', '4.414687']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '4.17416', '.764969', '7.80', '0.000', '2.914576', '5.978095']
# ['white', 'collar', '-', 'other', '|', '8.910133', '2.390351', '8.15', '0.000', '5.26659', '15.07436']
# ['blue', 'collar', '-', 'services', '|', '7.233931', '1.524022', '9.39', '0.000', '4.786806', '10.93208']
# ['blue', 'collar', '-', 'agriculture', '|', '1.224138', '.5265943', '0.47', '0.638', '.5268224', '2.844438']
# ['blue', 'collar', '-', 'artisans', '|', '2.538171', '.429107', '5.51', '0.000', '1.822282', '3.535301']
# ['blue', 'collar', '-', 'equip.', '|', '3.971039', '.7158179', '7.65', '0.000', '2.789119', '5.653813']
# ['unskilled', '|', '1.748481', '.3554963', '2.75', '0.006', '1.173808', '2.604503']
# ['|']
# ['public_servant', '|', '2.804504', '.6810991', '4.25', '0.000', '1.742345', '4.514171']
# ['parent_15', '|', '1.128915', '.1208958', '1.13', '0.258', '.9151786', '1.392569']
# ['part_time', '|', '.4154788', '.1409909', '-2.59', '0.010', '.2136473', '.8079796']
# ['college', '|', '2.072669', '.2561424', '5.90', '0.000', '1.626813', '2.64072']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.2370885', '.0910361', '-3.75', '0.000', '.1117043', '.5032118']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,761']
# ['Wald', 'chi2(22)', '=', '356.90']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-742282.39', 'Pseudo', 'R2', '=', '0.1186']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '2.768269', '1.076566', '2.62', '0.009', '1.291756', '5.93248']
# ['extractive', 'and', 'energy.', '|', '4.544728', '1.687062', '4.08', '0.000', '2.195487', '9.407733']
# ['manufactures,', 'sec.', '|', '3.413831', '1.308092', '3.20', '0.001', '1.610955', '7.234368']
# ['construction', '|', '.9799258', '.3468143', '-0.06', '0.954', '.4897076', '1.960873']
# ['hospitality', 'and', 'sales', '|', '1.866742', '.6565616', '1.77', '0.076', '.9369228', '3.719331']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.865851', '.6808671', '1.71', '0.087', '.9125678', '3.814948']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.347546', '.4859931', '0.83', '0.408', '.6645957', '2.732309']
# ['Education', 'and', 'healthcare', '|', '1.454862', '.5715822', '0.95', '0.340', '.6736027', '3.142241']
# ['Other', 'services', '|', '1.463063', '.6231727', '0.89', '0.372', '.6348988', '3.371485']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '3.383492', '.6969168', '5.92', '0.000', '2.259636', '5.066312']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '4.08876', '.7512627', '7.66', '0.000', '2.852286', '5.861248']
# ['white', 'collar', '-', 'other', '|', '7.896372', '2.005949', '8.13', '0.000', '4.799469', '12.99158']
# ['blue', 'collar', '-', 'services', '|', '5.629594', '1.139165', '8.54', '0.000', '3.786465', '8.369898']
# ['blue', 'collar', '-', 'agriculture', '|', '1.53585', '.65312', '1.01', '0.313', '.6673834', '3.534453']
# ['blue', 'collar', '-', 'artisans', '|', '2.390251', '.4130052', '5.04', '0.000', '1.703596', '3.353671']
# ['blue', 'collar', '-', 'equip.', '|', '4.077212', '.740153', '7.74', '0.000', '2.856546', '5.819496']
# ['unskilled', '|', '1.935355', '.4070557', '3.14', '0.002', '1.281536', '2.922743']
# ['|']
# ['public_servant', '|', '2.80655', '.6840058', '4.23', '0.000', '1.740684', '4.525074']
# ['parent_15', '|', '1.121233', '.1180653', '1.09', '0.277', '.9121466', '1.378247']
# ['part_time', '|', '.5425491', '.1736765', '-1.91', '0.056', '.2897072', '1.016059']
# ['college', '|', '1.774409', '.2068788', '4.92', '0.000', '1.411926', '2.229952']
# ['erte', '|', '1.127583', '1.47272', '0.09', '0.927', '.0871778', '14.58448']
# ['_cons', '|', '.1904131', '.0717569', '-4.40', '0.000', '.0909752', '.3985388']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '3,779']
# ['Wald', 'chi2(22)', '=', '340.44']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-747131.24', 'Pseudo', 'R2', '=', '0.1129']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ...
# ['parent_15', '|', '1.397195', '.1991057', '2.35', '0.019', '1.056714', '1.847382']
# ['part_time', '|', '.4064674', '.1176902', '-3.11', '0.002', '.2304441', '.7169453']
# ['college', '|', '2.053915', '.3511682', '4.21', '0.000', '1.46909', '2.871552']
# ['erte', '|', '1.248804', '1.221081', '0.23', '0.820', '.1837339', '8.487879']
# ['_cons', '|', '.229574', '.1039978', '-3.25', '0.001', '.0944769', '.5578531']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'success', 'perfectly;']
# ['erte', 'omitted', 'and', '5', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '1,855']
# ['Wald', 'chi2(21)', '=', '140.19']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-506053.2', 'Pseudo', 'R2', '=', '0.0885']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '2.702255', '1.149136', '2.34', '0.019', '1.174227', '6.218714']
# ['extractive', 'and', 'energy.', '|', '3.425285', '1.368829', '3.08', '0.002', '1.565076', '7.496492']
# ['manufactures,', 'sec.', '|', '4.738573', '2.00796', '3.67', '0.000', '2.065155', '10.87282']
# ['construction', '|', '1.154011', '.4451416', '0.37', '0.710', '.5418419', '2.457806']
# ['hospitality', 'and', 'sales', '|', '2.276024', '.8369292', '2.24', '0.025', '1.107074', '4.679256']
# ['Transport,', 'storage', 'and', 'IT.', '|', '2.635166', '1.0168', '2.51', '0.012', '1.236987', '5.613721']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.916059', '.7237174', '1.72', '0.085', '.9139034', '4.017144']
# ['Education', 'and', 'healthcare', '|', '1.491849', '.6568071', '0.91', '0.364', '.6294654', '3.535722']
# ['Other', 'services', '|', '2.255374', '1.233309', '1.49', '0.137', '.7722443', '6.586918']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '1.185967', '.3787036', '0.53', '0.593', '.6342589', '2.217577']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '1.849594', '.6075527', '1.87', '0.061', '.9715711', '3.521099']
# ['white', 'collar', '-', 'other', '|', '4.130672', '1.737232', '3.37', '0.001', '1.811473', '9.419101']
# ['blue', 'collar', '-', 'services', '|', '1.179285', '.4016045', '0.48', '0.628', '.6049822', '2.298766']
# ['blue', 'collar', '-', 'agriculture', '|', '.7638253', '.3908364', '-0.53', '0.599', '.2801875', '2.082281']
# ['blue', 'collar', '-', 'artisans', '|', '1.341132', '.4389737', '0.90', '0.370', '.7060894', '2.547318']
# ['blue', 'collar', '-', 'equip.', '|', '1.320206', '.4618812', '0.79', '0.427', '.6650349', '2.620832']
# ['unskilled', '|', '.6373074', '.246004', '-1.17', '0.243', '.2990754', '1.358055']
# ['|']
# ['public_servant', '|', '2.743128', '.8547247', '3.24', '0.001', '1.489437', '5.052076']
# ['parent_15', '|', '1.598392', '.2345578', '3.20', '0.001', '1.198872', '2.131051']
# ['part_time', '|', '.3371543', '.1310755', '-2.80', '0.005', '.1573646', '.7223546']
# ['college', '|', '1.540894', '.2971348', '2.24', '0.025', '1.055925', '2.2486']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.3817493', '.1813277', '-2.03', '0.043', '.1504751', '.9684825']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'success', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '1,835']
# ['Wald', 'chi2(21)', '=', '123.40']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-493698.59', 'Pseudo', 'R2', '=', '0.0752']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '4.14472', '1.814807', '3.25', '0.001', '1.757066', '9.776923']
# ['extractive', 'and', 'energy.', '|', '2.759739', '1.145433', '2.45', '0.014', '1.223421', '6.225301']
# ['manufactures,', 'sec.', '|', '3.335174', '1.441523', '2.79', '0.005', '1.429597', '7.780783']
# ['construction', '|', '1.049031', '.4096954', '0.12', '0.902', '.4879269', '2.255392']
# ['hospitality', 'and', 'sales', '|', '2.077718', '.7900429', '1.92', '0.054', '.9861002', '4.377762']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.673944', '.6579232', '1.31', '0.190', '.7747943', '3.616556']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.847508', '.7284892', '1.56', '0.120', '.8530014', '4.0015']
# ['Education', 'and', 'healthcare', '|', '1.157473', '.494752', '0.34', '0.732', '.5008087', '2.67516']
# ['Other', 'services', '|', '1.618678', '.8175641', '0.95', '0.340', '.6014983', '4.355986']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '1.731789', '.5541632', '1.72', '0.086', '.9249431', '3.242462']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '2.894414', '.9551729', '3.22', '0.001', '1.515861', '5.526649']
# ['white', 'collar', '-', 'other', '|', '4.858253', '1.996292', '3.85', '0.000', '2.171276', '10.87039']
# ['blue', 'collar', '-', 'services', '|', '1.722305', '.5751684', '1.63', '0.104', '.8950536', '3.314142']
# ['blue', 'collar', '-', 'agriculture', '|', '1.067358', '.553522', '0.13', '0.900', '.3862643', '2.949412']
# ['blue', 'collar', '-', 'artisans', '|', '1.899863', '.6146994', '1.98', '0.047', '1.007666', '3.58202']
# ['blue', 'collar', '-', 'equip.', '|', '2.168271', '.734154', '2.29', '0.022', '1.11662', '4.210382']
# ['unskilled', '|', '1.141733', '.4142861', '0.37', '0.715', '.5606603', '2.325033']
# ['|']
# ['public_servant', '|', '2.533082', '.7521316', '3.13', '0.002', '1.415492', '4.533055']
# ['parent_15', '|', '1.166161', '.1694001', '1.06', '0.290', '.8772239', '1.550268']
# ['part_time', '|', '.2809656', '.0928416', '-3.84', '0.000', '.1470226', '.5369357']
# ['college', '|', '1.628957', '.2824262', '2.81', '0.005', '1.159657', '2.288178']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.3837135', '.1803376', '-2.04', '0.042', '.1527423', '.9639503']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'failure', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '1,860']
# ['Wald', 'chi2(21)', '=', '132.61']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-492798.62', 'Pseudo', 'R2', '=', '0.0832']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '6.68253', '3.026454', '4.19', '0.000', '2.750678', '16.23462']
# ['extractive', 'and', 'energy.', '|', '3.383543', '1.523823', '2.71', '0.007', '1.399657', '8.179403']
# ['manufactures,', 'sec.', '|', '4.805743', '1.976606', '3.82', '0.000', '2.146152', '10.76119']
# ['construction', '|', '1.305327', '.476634', '0.73', '0.466', '.6381271', '2.670125']
# ['hospitality', 'and', 'sales', '|', '1.921611', '.6956688', '1.80', '0.071', '.9451707', '3.906795']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.867012', '.698781', '1.67', '0.095', '.8965224', '3.888059']
# ['Financial', 'and', 'prof.', 'serv.', '|', '2.250808', '.8534549', '2.14', '0.032', '1.070489', '4.732544']
# ['Education', 'and', 'healthcare', '|', '1.379415', '.6127395', '0.72', '0.469', '.5775492', '3.294585']
# ['Other', 'services', '|', '1.39375', '.6382134', '0.73', '0.468', '.5680808', '3.419475']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '1.306411', '.4260316', '0.82', '0.412', '.6894388', '2.475505']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '2.266145', '.7526389', '2.46', '0.014', '1.181909', '4.345016']
# ['white', 'collar', '-', 'other', '|', '3.913708', '1.734139', '3.08', '0.002', '1.642201', '9.327182']
# ['blue', 'collar', '-', 'services', '|', '2.087957', '.7041726', '2.18', '0.029', '1.078077', '4.043831']
# ['blue', 'collar', '-', 'agriculture', '|', '.5408574', '.2972112', '-1.12', '0.263', '.1842179', '1.587939']
# ['blue', 'collar', '-', 'artisans', '|', '1.496578', '.5005673', '1.21', '0.228', '.7769519', '2.882735']
# ['blue', 'collar', '-', 'equip.', '|', '1.692039', '.5901348', '1.51', '0.132', '.8541531', '3.351855']
# ['unskilled', '|', '.8217001', '.3084539', '-0.52', '0.601', '.3937178', '1.714911']
# ['|']
# ['public_servant', '|', '1.875721', '.624839', '1.89', '0.059', '.976375', '3.603462']
# ['parent_15', '|', '1.108478', '.1663812', '0.69', '0.493', '.8259675', '1.487618']
# ['part_time', '|', '.4560152', '.1447966', '-2.47', '0.013', '.2447377', '.8496846']
# ['college', '|', '1.536984', '.2724121', '2.43', '0.015', '1.085936', '2.175378']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.4722191', '.2142183', '-1.65', '0.098', '.1940899', '1.148905']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', 'omitted', 'because', 'of', 'collinearity.']
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '1,827']
# ['Wald', 'chi2(21)', '=', '85.79']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-488648.46', 'Pseudo', 'R2', '=', '0.0596']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '4.252809', '1.850356', '3.33', '0.001', '1.812702', '9.977584']
# ['extractive', 'and', 'energy.', '|', '2.664551', '1.217355', '2.15', '0.032', '1.088266', '6.523986']
# ['manufactures,', 'sec.', '|', '3.101042', '1.357386', '2.59', '0.010', '1.314984', '7.312989']
# ['construction', '|', '1.039789', '.3806977', '0.11', '0.915', '.507335', '2.131059']
# ['hospitality', 'and', 'sales', '|', '1.625748', '.5525199', '1.43', '0.153', '.8351557', '3.164747']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.150248', '.425978', '0.38', '0.705', '.556623', '2.37696']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.34609', '.5004497', '0.80', '0.424', '.6495526', '2.789549']
# ['Education', 'and', 'healthcare', '|', '1.226211', '.5120101', '0.49', '0.625', '.540931', '2.779639']
# ['Other', 'services', '|', '1.017334', '.4577918', '0.04', '0.970', '.4211435', '2.45752']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '1.638838', '.6235418', '1.30', '0.194', '.7774506', '3.454614']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '2.009053', '.7643147', '1.83', '0.067', '.9531564', '4.23466']
# ['white', 'collar', '-', 'other', '|', '5.851474', '2.958744', '3.49', '0.000', '2.172016', '15.76404']
# ['blue', 'collar', '-', 'services', '|', '1.87183', '.718815', '1.63', '0.103', '.8818409', '3.973218']
# ['blue', 'collar', '-', 'agriculture', '|', '.6894779', '.3805818', '-0.67', '0.501', '.2337058', '2.034095']
# ['blue', 'collar', '-', 'artisans', '|', '1.608571', '.6271855', '1.22', '0.223', '.7491258', '3.454026']
# ['blue', 'collar', '-', 'equip.', '|', '1.738842', '.7097637', '1.36', '0.175', '.7812949', '3.869948']
# ['unskilled', '|', '1.087136', '.4421606', '0.21', '0.837', '.4898725', '2.412599']
# ['|']
# ['public_servant', '|', '1.668793', '.5227673', '1.63', '0.102', '.9031391', '3.083547']
# ['parent_15', '|', '.9109556', '.1379695', '-0.62', '0.538', '.6769831', '1.225791']
# ['part_time', '|', '.5356181', '.1840932', '-1.82', '0.069', '.2730834', '1.050546']
# ['college', '|', '1.388576', '.2572486', '1.77', '0.076', '.9657737', '1.996475']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.8337859', '.4020757', '-0.38', '0.706', '.3240265', '2.1455']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['note:', 'erte', '!=', '0', 'predicts', 'failure', 'perfectly;']
# ['erte', 'omitted', 'and', '1', 'obs', 'not', 'used.']
# []
# []
# ['Logistic', 'regression', 'Number', 'of', 'obs', '=', '1,816']
# ['Wald', 'chi2(21)', '=', '95.13']
# ['Prob', '>', 'chi2', '=', '0.0000']
# ['Log', 'pseudolikelihood', '=', '-470776.6', 'Pseudo', 'R2', '=', '0.0708']
# []
# ['----------------------------------------------------------------------------------------------']
# ['|', 'Robust']
# ['permanent', '|', 'Odds', 'ratio', 'std.', 'err.', 'z', 'P>|z|', '[95%', 'conf.', 'interval]']
# ['-----------------------------+----------------------------------------------------------------']
# ['act', '|']
# ['manufactures,', 'prim.', '|', '3.681767', '1.533589', '3.13', '0.002', '1.627422', '8.329376']
# ['extractive', 'and', 'energy.', '|', '4.814877', '2.044929', '3.70', '0.000', '2.094454', '11.06877']
# ['manufactures,', 'sec.', '|', '7.820495', '3.373968', '4.77', '0.000', '3.357403', '18.2165']
# ['construction', '|', '1.124804', '.4070001', '0.33', '0.745', '.553449', '2.286001']
# ['hospitality', 'and', 'sales', '|', '1.51673', '.501016', '1.26', '0.207', '.7938415', '2.897895']
# ['Transport,', 'storage', 'and', 'IT.', '|', '1.401441', '.4996974', '0.95', '0.344', '.6967398', '2.818896']
# ['Financial', 'and', 'prof.', 'serv.', '|', '1.851564', '.6506654', '1.75', '0.080', '.9298538', '3.686912']
# ['Education', 'and', 'healthcare', '|', '1.449267', '.6002124', '0.90', '0.370', '.6436121', '3.263417']
# ['Other', 'services', '|', '.8977442', '.4194966', '-0.23', '0.817', '.3592563', '2.24337']
# ['|']
# ['occ', '|']
# ['white', 'collar', '-', 'prof.', '|', '1.646648', '.6087461', '1.35', '0.177', '.7978506', '3.398442']
# ['white', 'collar', '-', 'tech.', 'suport', '|', '2.36918', '.8728953', '2.34', '0.019', '1.150756', '4.877674']
# ['white', 'collar', '-', 'other', '|', '5.610186', '2.678606', '3.61', '0.000', '2.200734', '14.30167']
# ['blue', 'collar', '-', 'services', '|', '2.44786', '.9097242', '2.41', '0.016', '1.181532', '5.071397']
# ['blue', 'collar', '-', 'agriculture', '|', '1.817417', '.9041155', '1.20', '0.230', '.6854965', '4.818415']
# ['blue', 'collar', '-', 'artisans', '|', '2.288197', '.8441345', '2.24', '0.025', '1.110397', '4.715292']
# ['blue', 'collar', '-', 'equip.', '|', '3.159588', '1.236351', '2.94', '0.003', '1.467419', '6.8031']
# ['unskilled', '|', '1.751412', '.7092675', '1.38', '0.166', '.7919145', '3.873455']
# ['|']
# ['public_servant', '|', '1.463386', '.4719128', '1.18', '0.238', '.7777917', '2.753306']
# ['parent_15', '|', '.651855', '.1001881', '-2.78', '0.005', '.4823073', '.8810044']
# ['part_time', '|', '.615211', '.1931768', '-1.55', '0.122', '.3324651', '1.138419']
# ['college', '|', '1.253116', '.2424407', '1.17', '0.244', '.8576482', '1.830937']
# ['erte', '|', '1', '(omitted)']
# ['_cons', '|', '.7479457', '.3474799', '-0.63', '0.532', '.3008983', '1.859176']
# ['----------------------------------------------------------------------------------------------']
# ['Note:', '_cons', 'estimates', 'baseline', 'odds.']
# ['(file', './regtabs/tex/prob_perm_stocks_m_age3540_parent_5_cohab.csv', 'not', 'found)']
# ['(output', 'written', 'to', './regtabs/tex/prob_perm_stocks_m_age3540_parent_5_cohab.csv)']
# ['(file', './regtabs/tex/prob_perm_stocks_m_margins_age3540_parent_5_cohab.csv', 'not', 'found)']
# ['(output', 'written', 'to', './regtabs/tex/prob_perm_stocks_m_margins_age3540_parent_5_cohab.csv)']

# %%
t0 = int(np.where(np.array(qs)=='2018Q1')[0])
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs[t0:],coefs_par_a3045_p5[t0:],marker='o')
plt.scatter(qs[t0:],bounds_par_a3045_p5[t0:,0],marker='_',color=colors[0])
plt.scatter(qs[t0:],bounds_par_a3045_p5[t0:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p5[t0:].size):
    plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_par_a3045_p5[t0:,:][i,0],bounds_par_a3045_p5[t0:,:][i,1]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.0,2.)

# plt.subplot(122)
# plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
# plt.plot(qs[t0:],coefs_m_par_a3045_p5[t0:],color=colors[2],marker='o')
# plt.scatter(qs[t0:],bounds_m_par_a3045_p5[t0:,0],marker='_',color=colors[2])
# plt.scatter(qs[t0:],bounds_m_par_a3045_p5[t0:,1],marker='_',color=colors[2])
# for i in range(coefs_m_par_a3045_p5[t0:].size):
#     plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_m_par_a3045_p5[t0:,0][i],bounds_m_par_a3045_p5[t0:,1][i]),c=colors[2])
# plt.xticks(rotation=90)
# plt.axhline(1,color='r',lw=1)
# plt.ylim(0.6,1.6)
# plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_5.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs,coefs_par_a3045_p5,marker='o')
plt.scatter(qs,bounds_par_a3045_p5[:,0],marker='_',color=colors[0])
plt.scatter(qs,bounds_par_a3045_p5[:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p5.size):
    plt.plot((qs[i],qs[i]),(bounds_par_a3045_p5[i,0],bounds_par_a3045_p5[i,1]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.6)

plt.subplot(122)
plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
plt.plot(qs,coefs_m_par_a3045_p5,color=colors[2],marker='o')
plt.scatter(qs,bounds_m_par_a3045_p5[:,0],marker='_',color=colors[2])
plt.scatter(qs,bounds_m_par_a3045_p5[:,1],marker='_',color=colors[2])
for i in range(coefs_m_par_a3045_p5.size):
    plt.plot((qs[i],qs[i]),(bounds_m_par_a3045_p5[i,0],bounds_m_par_a3045_p5[i,1]),c=colors[2])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.6)
plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_5.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Children Age <10

# %%
coefs_par_a3045_p10 = []
coefs_mar_a3045_p10 = []
coefs_parxmar_a3045_p10 = []
coefs_div_a3045_p10 = []
bounds_par_a3045_p10 = []
bounds_mar_a3045_p10 = []
bounds_parxmar_a3045_p10 = []
bounds_div_a3045_p10 = []
qs = []
cc = 130
f = open('./regtabs/prob_perm_stocks_w_age3540_parent_10_cohab.log','r')
for line in f:
    words = line.split()
    #print(words)
    if  len(words)>1 and words[0]=='permanent' and words[1]=='|':
        #indx_if = words.index("if")
        #ciclo = int(words[indx_if+1][7:10])
        ciclo = cc
        qs.append(date_dict[ciclo])
        cc +=1
    if len(words)>0 and 'parent_10'==words[0]:
        coefs_par_a3045_p10.append(float(words[2]))
        bounds_par_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_mar_a3045_p10.append(float(words[2]))
        bounds_mar_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_10'==words[0]:
        coefs_parxmar_a3045_p10.append(float(words[2]))
        bounds_parxmar_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_div_a3045_p10.append(float(words[2]))
        bounds_div_a3045_p10.append((float(words[-2]),float(words[-1])))
bounds_par_a3045_p10 = np.array(bounds_par_a3045_p10)
coefs_par_a3045_p10 = np.array(coefs_par_a3045_p10)
bounds_mar_a3045_p10 = np.array(bounds_mar_a3045_p10)
coefs_mar_a3045_p10 = np.array(coefs_mar_a3045_p10)
bounds_parxmar_a3045_p10 = np.array(bounds_parxmar_a3045_p10)
coefs_parxmar_a3045_p10 = np.array(coefs_parxmar_a3045_p10)
bounds_div_a3045_p10 = np.array(bounds_div_a3045_p10)
coefs_div_a3045_p10 = np.array(coefs_div_a3045_p10)

# %%
coefs_m_par_a3045_p10 = []
coefs_m_mar_a3045_p10 = []
coefs_m_parxmar_a3045_p10 = []
coefs_m_div_a3045_p10 = []
bounds_m_par_a3045_p10 = []
bounds_m_mar_a3045_p10 = []
bounds_m_parxmar_a3045_p10 = []
bounds_m_div_a3045_p10 = []
f = open('./regtabs/prob_perm_stocks_m_age3540_parent_10.log','r')
for line in f:
    words = line.split()
    if len(words)>0 and 'parent_10'==words[0]:        
        coefs_m_par_a3045_p10.append(float(words[2]))
        bounds_m_par_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_m_mar_a3045_p10.append(float(words[2]))
        bounds_m_mar_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_10'==words[0]:
        coefs_m_parxmar_a3045_p10.append(float(words[2]))
        bounds_m_parxmar_a3045_p10.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_m_div_a3045_p10.append(float(words[2]))
        bounds_m_div_a3045_p10.append((float(words[-2]),float(words[-1])))
bounds_m_par_a3045_p10 = np.array(bounds_m_par_a3045_p10)
coefs_m_par_a3045_p10 = np.array(coefs_m_par_a3045_p10)
bounds_m_mar_a3045_p10 = np.array(bounds_m_mar_a3045_p10)
coefs_m_mar_a3045_p10 = np.array(coefs_m_mar_a3045_p10)
bounds_m_parxmar_a3045_p10 = np.array(bounds_m_parxmar_a3045_p10)
coefs_m_parxmar_a3045_p10 = np.array(coefs_m_parxmar_a3045_p10)
bounds_m_div_a3045_p10 = np.array(bounds_m_div_a3045_p10)
coefs_m_div_a3045_p10 = np.array(coefs_m_div_a3045_p10)

# %%
t0 = int(np.where(np.array(qs)=='2018Q1')[0])
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs[t0:],coefs_par_a3045_p10[t0:],marker='o')
plt.scatter(qs[t0:],bounds_par_a3045_p10[t0:,0],marker='_',color=colors[0])
plt.scatter(qs[t0:],bounds_par_a3045_p10[t0:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p10[t0:].size):
    plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_par_a3045_p10[t0:,0][i],bounds_par_a3045_p10[t0:,1][i]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.0,2.25)

plt.subplot(122)
plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
plt.plot(qs[t0:],coefs_m_par_a3045_p10[t0:],color=colors[2],marker='o')
plt.scatter(qs[t0:],bounds_m_par_a3045_p10[t0:,0],marker='_',color=colors[2])
plt.scatter(qs[t0:],bounds_m_par_a3045_p10[t0:,1],marker='_',color=colors[2])
for i in range(coefs_m_par_a3045_p10[t0:].size):
    plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_m_par_a3045_p10[t0:,0][i],bounds_m_par_a3045_p10[t0:,1][i]),c=colors[2])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.,2.25)
plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_10.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs,coefs_par_a3045_p10,marker='o')
plt.scatter(qs,bounds_par_a3045_p10[:,0],marker='_',color=colors[0])
plt.scatter(qs,bounds_par_a3045_p10[:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p10.size):
    plt.plot((qs[i],qs[i]),(bounds_par_a3045_p10[i,0],bounds_par_a3045_p10[i,1]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.6)

plt.subplot(122)
plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
plt.plot(qs,coefs_m_par_a3045_p10,color=colors[2],marker='o')
plt.scatter(qs,bounds_m_par_a3045_p10[:,0],marker='_',color=colors[2])
plt.scatter(qs,bounds_m_par_a3045_p10[:,1],marker='_',color=colors[2])
for i in range(coefs_m_par_a3045_p10.size):
    plt.plot((qs[i],qs[i]),(bounds_m_par_a3045_p10[i,0],bounds_m_par_a3045_p10[i,1]),c=colors[2])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.8)
plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_10.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Children Age <15

# %%
coefs_par_a3045_p15 = []
coefs_mar_a3045_p15 = []
coefs_parxmar_a3045_p15 = []
coefs_div_a3045_p15 = []
bounds_par_a3045_p15 = []
bounds_mar_a3045_p15 = []
bounds_parxmar_a3045_p15 = []
bounds_div_a3045_p15 = []
qs = []
cc = 130
f = open('./regtabs/prob_perm_stocks_w_age3540_parent_15_cohab.log','r')
for line in f:
    words = line.split()
    #print(words)
    if  len(words)>1 and words[0]=='permanent' and words[1]=='|':
        #indx_if = words.index("if")
        #ciclo = int(words[indx_if+1][7:10])
        ciclo = cc
        qs.append(date_dict[ciclo])
        cc +=1
    if len(words)>0 and 'parent_15'==words[0]:
        coefs_par_a3045_p15.append(float(words[2]))
        bounds_par_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_mar_a3045_p15.append(float(words[2]))
        bounds_mar_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_15'==words[0]:
        coefs_parxmar_a3045_p15.append(float(words[2]))
        bounds_parxmar_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_div_a3045_p15.append(float(words[2]))
        bounds_div_a3045_p15.append((float(words[-2]),float(words[-1])))
bounds_par_a3045_p15 = np.array(bounds_par_a3045_p15)
coefs_par_a3045_p15 = np.array(coefs_par_a3045_p15)
bounds_mar_a3045_p15 = np.array(bounds_mar_a3045_p15)
coefs_mar_a3045_p15 = np.array(coefs_mar_a3045_p15)
bounds_parxmar_a3045_p15 = np.array(bounds_parxmar_a3045_p15)
coefs_parxmar_a3045_p15 = np.array(coefs_parxmar_a3045_p15)
bounds_div_a3045_p15 = np.array(bounds_div_a3045_p15)
coefs_div_a3045_p15 = np.array(coefs_div_a3045_p15)

# %%
coefs_m_par_a3045_p15 = []
coefs_m_mar_a3045_p15 = []
coefs_m_parxmar_a3045_p15 = []
coefs_m_div_a3045_p15 = []
bounds_m_par_a3045_p15 = []
bounds_m_mar_a3045_p15 = []
bounds_m_parxmar_a3045_p15 = []
bounds_m_div_a3045_p15 = []
f = open('./regtabs/prob_perm_stocks_m_age3540_parent_15_cohab.log','r')
for line in f:
    words = line.split()
    if len(words)>0 and 'parent_15'==words[0]:        
        coefs_m_par_a3045_p15.append(float(words[2]))
        bounds_m_par_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married'==words[0]:
        coefs_m_mar_a3045_p15.append(float(words[2]))
        bounds_m_mar_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'married_parent_15'==words[0]:
        coefs_m_parxmar_a3045_p15.append(float(words[2]))
        bounds_m_parxmar_a3045_p15.append((float(words[-2]),float(words[-1])))
    elif len(words)>0 and 'divorced'==words[0]:
        coefs_m_div_a3045_p15.append(float(words[2]))
        bounds_m_div_a3045_p15.append((float(words[-2]),float(words[-1])))
bounds_m_par_a3045_p15 = np.array(bounds_m_par_a3045_p15)
coefs_m_par_a3045_p15 = np.array(coefs_m_par_a3045_p15)
bounds_m_mar_a3045_p15 = np.array(bounds_m_mar_a3045_p15)
coefs_m_mar_a3045_p15 = np.array(coefs_m_mar_a3045_p15)
bounds_m_parxmar_a3045_p15 = np.array(bounds_m_parxmar_a3045_p15)
coefs_m_parxmar_a3045_p15 = np.array(coefs_m_parxmar_a3045_p15)
bounds_m_div_a3045_p15 = np.array(bounds_m_div_a3045_p15)
coefs_m_div_a3045_p15 = np.array(coefs_m_div_a3045_p15)

# %%
t0 = int(np.where(np.array(qs)=='2015Q1')[0])
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs[t0:],coefs_par_a3045_p15[t0:],marker='o')
plt.scatter(qs[t0:],bounds_par_a3045_p15[t0:,0],marker='_',color=colors[0])
plt.scatter(qs[t0:],bounds_par_a3045_p15[t0:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p15[t0:].size):
    plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_par_a3045_p15[t0:,0][i],bounds_par_a3045_p15[t0:,1][i]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.0,2.25)

plt.subplot(122)
plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
plt.plot(qs[t0:],coefs_m_par_a3045_p15[t0:],color=colors[2],marker='o')
plt.scatter(qs[t0:],bounds_m_par_a3045_p15[t0:,0],marker='_',color=colors[2])
plt.scatter(qs[t0:],bounds_m_par_a3045_p15[t0:,1],marker='_',color=colors[2])
for i in range(coefs_m_par_a3045_p15[t0:].size):
    plt.plot((qs[t0:][i],qs[t0:][i]),(bounds_m_par_a3045_p15[t0:,0][i],bounds_m_par_a3045_p15[t0:,1][i]),c=colors[2])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.,2.25)
plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_10.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
colors = sn.color_palette()
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.title("Odds-ratio effect of parent=1, women",fontsize=16)
plt.plot(qs,coefs_par_a3045_p15,marker='o')
plt.scatter(qs,bounds_par_a3045_p15[:,0],marker='_',color=colors[0])
plt.scatter(qs,bounds_par_a3045_p15[:,1],marker='_',color=colors[0])
for i in range(coefs_par_a3045_p15.size):
    plt.plot((qs[i],qs[i]),(bounds_par_a3045_p15[i,0],bounds_par_a3045_p15[i,1]),c=colors[0])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.6)

plt.subplot(122)
plt.title("Odds-ratio effect of parent=1, men",fontsize=16)
plt.plot(qs,coefs_m_par_a3045_p15,color=colors[2],marker='o')
plt.scatter(qs,bounds_m_par_a3045_p15[:,0],marker='_',color=colors[2])
plt.scatter(qs,bounds_m_par_a3045_p15[:,1],marker='_',color=colors[2])
for i in range(coefs_m_par_a3045_p15.size):
    plt.plot((qs[i],qs[i]),(bounds_m_par_a3045_p15[i,0],bounds_m_par_a3045_p15[i,1]),c=colors[2])
plt.xticks(rotation=90)
plt.axhline(1,color='r',lw=1)
plt.ylim(0.6,1.8)
plt.tight_layout()
# plt.savefig('./plots_logit/prob_womenVmen_parent_time_age3045_parent_15.pdf',format='pdf',bbox_inches='tight')
plt.show()
