# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.optimize import fsolve

pd.set_option('display.max_rows', None)

sn.set_style('whitegrid')
# %matplotlib inline

# %%
# Expanded and modified version (first column now string)
def read_table(filename,keyword='ciclo',rescale=1,ncols=5,start=2,end_row='Total',
               endword=None,omit_list=['t20_21'],index_to_int=True,debug=False):
    t0 = start
    t1 = ncols+start
    results_follow = 0
    row_names = []
    interaction = 0
    f = open(filename,'r')
    for line in f:
        words = line.split()
        if debug:
            print(words)
        if len(words)>1 and words[0] == keyword:
            results_follow=1
            if endword==None:
                colnames = words[t0:t1]
            else:
                buff_v = []
                for w in words[t0:]:
                    if w==endword:
                        break
                    else:
                        buff_v.append(w)
                colnames = buff_v[:-1]
                t1 = len(buff_v)+t0-1
            table_raw = np.empty(t1-t0)
        elif len(words)>1 and words[0] == end_row:
            break
        elif len(words) == 1:
            interaction = 0
            i_count = 0
        elif len(words)>1 and results_follow==1: # and words[0] not in omit_list
            if (len(words)==2 and words[1]=="|") or (len(words)==3 and words[2]=="|"):
                var_name = words[0]
                interaction = 1
                i_count = 0
            else:
                if interaction==0:
                    row_names.append(words[0])
                else:
                    end_idx = words.index("|")
                    new_name = var_name+"_{}"*end_idx
                    new_name = new_name.format(*words[:end_idx])
                    row_names.append(new_name)                 
                if words[2]=='|':
                    t00= t0+1
                    t11 = t1+1
                elif words[3]=='|':
                    t00= t0+2
                    t11 = t1+2
                else:
                    t00 = t0
                    t11 = t1

                buff_v = []
                for w in words[t00:t11]: 
                    w = w.replace(",","")
                    buff_v.append(w)
                table_raw = np.vstack((table_raw,np.array(buff_v,dtype=float)/rescale))
        
    table_raw = table_raw[1:,:]
    if debug:
        print(table_raw.shape)
        print(colnames)
    if index_to_int:
        return pd.DataFrame(table_raw, columns=colnames,index=np.array(row_names,dtype=int))
    else:
        return pd.DataFrame(table_raw, columns=colnames,index=np.array(row_names))
    
    
def file_split(filename,path,startwords=['Summary',],endword="Total",header=None,Noobs=False):
    f = open(path+filename,'r')
    parent_file = filename[:filename.find('.')]
    di = 1
    R2s = []
    writing = 0
    for line in f:
        words = line.split()
        if len(words)>0 and 'Number' in words:
            noobs = words[-1]
        if len(words)>0 and 'R2' in words:
            R2s.append(words[-1])
        if len(words)>0 and words[0] in startwords:
            sf = open(path+parent_file+'_{}.log'.format(di), "w")
            writing = 1
            if header!=None:
                sf.write(header)
        elif len(words)>0 and words[0]==endword and writing:
            sf.write(line)
            writing = 0
            sf.close()
            di+=1
        if writing:
            sf.write(line)
    if Noobs==True:
        return (noobs,R2s)
            
def normalise_table(table):
    cols = table.columns
    table['Total'] = table.sum(axis=1).copy()
    for col in cols:
        table[col] = table[col]/table['Total']
    return table

# %%
industry_dict = {"0": "agriculture", "1" :"manufactures, primary", "2": "extractive and energy", "3": "manufactures, secondary",
                 "4": "construction", "5": "hospitality and sales", "6": "Transport, storage and IT.",
                 "7": "Financial and prof. serv.", "8": "Education and healthcare", "9": "Other services"}

# %%
dates = []
for year in range(1987,2023):
    for quarter in range(1,5):
        dates.append(str(year)+"Q"+str(quarter))
dates = dates[1:]

t0 = 59
t05 = 71
T = len(dates)
date_dict = dict(zip(range(t0,T+t0),dates))
date_dict_reverse = dict(zip(dates,range(0,T)))
date_dict_reverse_ciclo = dict(zip(dates,range(t0,T+t0)))

# %% [markdown]
# ## Reading the regression table
#
# From log file to pandas

# %%
path = './tables/'
omits = ['sexo1#c.ttrend','sexo1#c.ttrend2',"covid#sexo1","sexo1#act1","covid#sexo1#act1","sexo1#c.urate","act1","covid#act1"]
# int_subs ={}
# for t in time_periods:
#     int_subs[t] = 'ten_'+t[1:]
name = "sqtreg_table_industry_age3040_10_agefix"
N, r2s = file_split('{}.log'.format(name),path,startwords=['q25','q50','q75'],endword="_cons",
           header="ten_y | Coefficient std t p_stat lower_95 upper_95",Noobs=True)

tab_moms_25 = read_table(path+'{}_1.log'.format(name),
                         keyword='ten_y',rescale=1,ncols=6,start=2,omit_list=omits,index_to_int=False)
tab_moms_50 = read_table(path+'{}_2.log'.format(name),
                         keyword='ten_y',rescale=1,ncols=6,start=2,omit_list=omits,index_to_int=False)
tab_moms_75 = read_table(path+'{}_3.log'.format(name),
                         keyword='ten_y',rescale=1,ncols=6,start=2,omit_list=omits,index_to_int=False)

# %%
tab_moms_25[:]
# Out:
#                         Coefficient       std      t  p_stat  lower_95  \
# ttrend                    -0.008587  0.000946  -9.08   0.000 -0.010441
# sexo1#c.ttrend_1           0.014431  0.001160  12.44   0.000  0.012156
# sexo1#c.urate_0            0.026863  0.002389  11.25   0.000  0.022181
# sexo1#c.urate_1            0.072734  0.002445  29.75   0.000  0.067942
# act1_1                     2.320372  0.083373  27.83   0.000  2.156965
# act1_2                     2.680730  0.044189  60.66   0.000  2.594120
# act1_3                     3.072955  0.056345  54.54   0.000  2.962520
# act1_4                     0.439948  0.023707  18.56   0.000  0.393484
# act1_5                     1.789399  0.044490  40.22   0.000  1.702201
# act1_6                     1.551304  0.047825  32.44   0.000  1.457568
# act1_7                     2.567055  0.055260  46.45   0.000  2.458746
# act1_8                     5.112573  0.064371  79.42   0.000  4.986408
# act1_9                     1.498577  0.067498  22.20   0.000  1.366282
# covid#act1_1_0             0.511227  0.116007   4.41   0.000  0.283858
# covid#act1_1_1            -0.464538  0.160953  -2.89   0.004 -0.780001
# covid#act1_1_2             0.278344  0.130332   2.14   0.033  0.022898
# covid#act1_1_3             0.104939  0.195420   0.54   0.591 -0.278078
# covid#act1_1_4             0.665886  0.108366   6.14   0.000  0.453491
# covid#act1_1_5             0.154085  0.143506   1.07   0.283 -0.127183
# covid#act1_1_6             0.157770  0.153518   1.03   0.304 -0.143121
# covid#act1_1_7             0.444173  0.140181   3.17   0.002  0.169422
# covid#act1_1_8             0.346501  0.413107   0.84   0.402 -0.463176
# covid#act1_1_9             1.944907  0.332379   5.85   0.000  1.293455
# covid#act1_2_0             0.590348  0.128976   4.58   0.000  0.337559
# covid#act1_2_1             0.561694  0.403645   1.39   0.164 -0.229439
# covid#act1_2_2            -0.090382  0.278354  -0.32   0.745 -0.635947
# covid#act1_2_3             0.295048  0.375985   0.78   0.433 -0.441872
# covid#act1_2_4             0.900400  0.163204   5.52   0.000  0.580525
# covid#act1_2_5             0.911937  0.199910   4.56   0.000  0.520120
# covid#act1_2_6            -0.183301  0.164516  -1.11   0.265 -0.505748
# covid#act1_2_7             0.523293  0.193117   2.71   0.007  0.144790
# covid#act1_2_8            -0.438892  0.303101  -1.45   0.148 -1.032961
# covid#act1_2_9             1.050156  0.808731   1.30   0.194 -0.534933
# covid#act1_3_0             0.755855  0.186140   4.06   0.000  0.391026
# covid#act1_3_1             0.102149  0.519331   0.20   0.844 -0.915725
# covid#act1_3_2             0.080659  0.452077   0.18   0.858 -0.805399
# covid#act1_3_3             0.892077  0.256601   3.48   0.001  0.389147
# covid#act1_3_4             1.108417  0.135165   8.20   0.000  0.843497
# covid#act1_3_5             1.221989  0.200264   6.10   0.000  0.829478
# covid#act1_3_6            -0.212116  0.155938  -1.36   0.174 -0.517750
# covid#act1_3_7             0.194334  0.193680   1.00   0.316 -0.185272
# covid#act1_3_8            -1.440051  0.261517  -5.51   0.000 -1.952617
# covid#act1_3_9             1.176264  0.536112   2.19   0.028  0.125500
# sexo1#act1_1_0            -1.400613  0.079727 -17.57   0.000 -1.556874
# sexo1#act1_1_1            -1.887652  0.124907 -15.11   0.000 -2.132466
# sexo1#act1_1_2            -0.886607  0.123397  -7.18   0.000 -1.128463
# sexo1#act1_1_3            -1.361638  0.163451  -8.33   0.000 -1.681997
# sexo1#act1_1_4             0.100755  0.093126   1.08   0.279 -0.081769
# sexo1#act1_1_5            -1.642517  0.060022 -27.37   0.000 -1.760159
# sexo1#act1_1_6            -0.205802  0.119310  -1.72   0.085 -0.439646
# sexo1#act1_1_7            -1.532195  0.062251 -24.61   0.000 -1.654206
# sexo1#act1_1_8            -3.552412  0.092763 -38.30   0.000 -3.734225
# sexo1#act1_1_9            -2.065856  0.068774 -30.04   0.000 -2.200651
# covid#sexo1#act1_1_1_0    -0.512782  0.124282  -4.13   0.000 -0.756370
# covid#sexo1#act1_1_1_1     0.462984  0.245400   1.89   0.059 -0.017993
# covid#sexo1#act1_1_1_2    -0.032478  0.599432  -0.05   0.957 -1.207347
# covid#sexo1#act1_1_1_3    -1.109601  0.618588  -1.79   0.073 -2.322016
# covid#sexo1#act1_1_1_4    -0.584698  0.439114  -1.33   0.183 -1.445349
# covid#sexo1#act1_1_1_5    -0.095742  0.241925  -0.40   0.692 -0.569907
# covid#sexo1#act1_1_1_6    -1.143410  0.397514  -2.88   0.004 -1.922526
# covid#sexo1#act1_1_1_7    -0.857141  0.227959  -3.76   0.000 -1.303934
# covid#sexo1#act1_1_1_8    -0.880133  0.430157  -2.05   0.041 -1.723227
# covid#sexo1#act1_1_1_9    -1.422403  0.358635  -3.97   0.000 -2.125318
# covid#sexo1#act1_2_1_0    -0.636133  0.125020  -5.09   0.000 -0.881167
# covid#sexo1#act1_2_1_1    -0.617239  0.698580  -0.88   0.377 -1.986434
# covid#sexo1#act1_2_1_2    -0.400138  0.492607  -0.81   0.417 -1.365634
# covid#sexo1#act1_2_1_3    -1.452763  0.453792  -3.20   0.001 -2.342182
# covid#sexo1#act1_2_1_4    -0.516432  0.366105  -1.41   0.158 -1.233987
# covid#sexo1#act1_2_1_5    -0.839079  0.238438  -3.52   0.000 -1.306411
# covid#sexo1#act1_2_1_6    -0.859127  0.291044  -2.95   0.003 -1.429565
# covid#sexo1#act1_2_1_7    -1.254550  0.249109  -5.04   0.000 -1.742795
# covid#sexo1#act1_2_1_8    -0.234333  0.309769  -0.76   0.449 -0.841471
# covid#sexo1#act1_2_1_9    -0.522368  0.797778  -0.65   0.513 -2.085990
# covid#sexo1#act1_3_1_0    -0.581728  0.255818  -2.27   0.023 -1.083124
# covid#sexo1#act1_3_1_1    -0.346585  0.516858  -0.67   0.503 -1.359612
# covid#sexo1#act1_3_1_2    -1.603163  0.674701  -2.38   0.017 -2.925556
# covid#sexo1#act1_3_1_3    -1.913213  0.508684  -3.76   0.000 -2.910219
# covid#sexo1#act1_3_1_4    -0.292273  0.809946  -0.36   0.718 -1.879743
# covid#sexo1#act1_3_1_5    -0.973792  0.215749  -4.51   0.000 -1.396654
# covid#sexo1#act1_3_1_6    -1.276539  0.413176  -3.09   0.002 -2.086352
# covid#sexo1#act1_3_1_7    -1.230390  0.260358  -4.73   0.000 -1.740684
# covid#sexo1#act1_3_1_8     0.941636  0.326332   2.89   0.004  0.302036
# covid#sexo1#act1_3_1_9    -1.026848  0.562036  -1.83   0.068 -2.128422
# _cons                      0.168423  0.023304   7.23   0.000  0.122748
#
#                         upper_95q25
# ttrend                    -0.006733
# sexo1#c.ttrend_1           0.016705
# sexo1#c.urate_0            0.031545
# sexo1#c.urate_1            0.077526
# act1_1                     2.483780
# act1_2                     2.767339
# act1_3                     3.183390
# act1_4                     0.486412
# act1_5                     1.876598
# act1_6                     1.645041
# act1_7                     2.675363
# act1_8                     5.238737
# act1_9                     1.630871
# covid#act1_1_0             0.738597
# covid#act1_1_1            -0.149076
# covid#act1_1_2             0.533791
# covid#act1_1_3             0.487955
# covid#act1_1_4             0.878281
# covid#act1_1_5             0.435352
# covid#act1_1_6             0.458660
# covid#act1_1_7             0.718924
# covid#act1_1_8             1.156179
# covid#act1_1_9             2.596360
# covid#act1_2_0             0.843137
# covid#act1_2_1             1.352826
# covid#act1_2_2             0.455183
# covid#act1_2_3             1.031968
# covid#act1_2_4             1.220274
# covid#act1_2_5             1.303754
# covid#act1_2_6             0.139146
# covid#act1_2_7             0.901796
# covid#act1_2_8             0.155177
# covid#act1_2_9             2.635245
# covid#act1_3_0             1.120684
# covid#act1_3_1             1.120023
# covid#act1_3_2             0.966716
# covid#act1_3_3             1.395006
# covid#act1_3_4             1.373338
# covid#act1_3_5             1.614500
# covid#act1_3_6             0.093518
# covid#act1_3_7             0.573940
# covid#act1_3_8            -0.927485
# covid#act1_3_9             2.227028
# sexo1#act1_1_0            -1.244351
# sexo1#act1_1_1            -1.642837
# sexo1#act1_1_2            -0.644752
# sexo1#act1_1_3            -1.041280
# sexo1#act1_1_4             0.283279
# sexo1#act1_1_5            -1.524875
# sexo1#act1_1_6             0.028042
# sexo1#act1_1_7            -1.410185
# sexo1#act1_1_8            -3.370598
# sexo1#act1_1_9            -1.931061
# covid#sexo1#act1_1_1_0    -0.269193
# covid#sexo1#act1_1_1_1     0.943961
# covid#sexo1#act1_1_1_2     1.142390
# covid#sexo1#act1_1_1_3     0.102814
# covid#sexo1#act1_1_1_4     0.275953
# covid#sexo1#act1_1_1_5     0.378423
# covid#sexo1#act1_1_1_6    -0.364293
# covid#sexo1#act1_1_1_7    -0.410348
# covid#sexo1#act1_1_1_8    -0.037038
# covid#sexo1#act1_1_1_9    -0.719489
# covid#sexo1#act1_2_1_0    -0.391098
# covid#sexo1#act1_2_1_1     0.751957
# covid#sexo1#act1_2_1_2     0.565358
# covid#sexo1#act1_2_1_3    -0.563343
# covid#sexo1#act1_2_1_4     0.201122
# covid#sexo1#act1_2_1_5    -0.371746
# covid#sexo1#act1_2_1_6    -0.288689
# covid#sexo1#act1_2_1_7    -0.766305
# covid#sexo1#act1_2_1_8     0.372804
# covid#sexo1#act1_2_1_9     1.041254
# covid#sexo1#act1_3_1_0    -0.080332
# covid#sexo1#act1_3_1_1     0.666442
# covid#sexo1#act1_3_1_2    -0.280770
# covid#sexo1#act1_3_1_3    -0.916207
# covid#sexo1#act1_3_1_4     1.295197
# covid#sexo1#act1_3_1_5    -0.550930
# covid#sexo1#act1_3_1_6    -0.466726
# covid#sexo1#act1_3_1_7    -0.720096
# covid#sexo1#act1_3_1_8     1.581237
# covid#sexo1#act1_3_1_9     0.074725
# _cons                      0.214098

# %%
new_names_var = ['$t$', '$t$ x female', 'unemployment rate x male',
       'unemployment rate x female', 'Manufactures prim.',
       'Extractive + energy', 'Manufactures sec.', 'Construction',
       'Hospitality + Sales', 'Transport, Storage + IT',
       'Financial + porf. serv.', 'Education + Health', 'Other Services',
       '$\\delta_{2020}$ x Agriculture',
       '$\\delta_{2020}$ x Manufactures prim.',
       '$\\delta_{2020}$ x Extractive + energy',
       '$\\delta_{2020}$ x Manufactures sec.',
       '$\\delta_{2020}$ x Construction',
       '$\\delta_{2020}$ x Hospitality + Sales',
       '$\\delta_{2020}$ x Transport, Storage + IT',
       '$\\delta_{2020}$ x Financial + porf. serv.',
       '$\\delta_{2020}$ x Education + Health',
       '$\\delta_{2020}$ x Other Services',
       '$\\delta_{2021}$ x Agriculture',
       '$\\delta_{2021}$ x Manufactures prim.',
       '$\\delta_{2021}$ x Extractive + energy',
       '$\\delta_{2021}$ x Manufactures sec.',
       '$\\delta_{2021}$ x Construction',
       '$\\delta_{2021}$ x Hospitality + Sales',
       '$\\delta_{2021}$ x Transport, Storage + IT',
       '$\\delta_{2021}$ x Financial + porf. serv.',
       '$\\delta_{2021}$ x Education + Health',
       '$\\delta_{2021}$ x Other Services',
       '$\\delta_{2022}$ x Agriculture',
       '$\\delta_{2022}$ x Manufactures prim.',
       '$\\delta_{2022}$ x Extractive + energy',
       '$\\delta_{2022}$ x Manufactures sec.',
       '$\\delta_{2022}$ x Construction',
       '$\\delta_{2022}$ x Hospitality + Sales',
       '$\\delta_{2022}$ x Transport, Storage + IT',
       '$\\delta_{2022}$ x Financial + porf. serv.',
       '$\\delta_{2022}$ x Education + Health',
       '$\\delta_{2022}$ x Other Services', 
       'Agriculture x female',
       'Manufactures prim. x female', 
       'Extractive + energy x female',
       'Manufactures sec. x female',
        'Construction x female',
       'Hospitality + Sales x female', 
        'Transport, Storage + IT x female',
       'Financial + porf. serv. x female', 
        'Education + Health x female',
       'Other Services x female',
       '$\\delta_{2020}$ x Agriculture x female',
       '$\\delta_{2020}$ x Manufactures prim. x female',
       '$\\delta_{2020}$ x Extractive + energy x female',
       '$\\delta_{2020}$ x Manufactures sec. x female',
       '$\\delta_{2020}$ x Construction x female',
       '$\\delta_{2020}$ x Hospitality + Sales x female',
       '$\\delta_{2020}$ x Transport, Storage + IT x female',
       '$\\delta_{2020}$ x Financial + porf. serv. x female',
       '$\\delta_{2020}$ x Education + Health x female',
       '$\\delta_{2020}$ x Other Services x female',
       '$\\delta_{2021}$ x Agriculture x female',
       '$\\delta_{2021}$ x Manufactures prim. x female',
       '$\\delta_{2021}$ x Extractive + energy x female',
       '$\\delta_{2021}$ x Manufactures sec. x female',
       '$\\delta_{2021}$ x Construction x female',
       '$\\delta_{2021}$ x Hospitality + Sales x female',
       '$\\delta_{2021}$ x Transport, Storage + IT x female',
       '$\\delta_{2021}$ x Financial + porf. serv. x female',
       '$\\delta_{2021}$ x Education + Health x female',
       '$\\delta_{2021}$ x Other Services x female',
       '$\\delta_{2022}$ x Agriculture x female',
       '$\\delta_{2022}$ x Manufactures prim. x female',
       '$\\delta_{2022}$ x Extractive + energy x female',
       '$\\delta_{2022}$ x Manufactures sec. x female',
       '$\\delta_{2022}$ x Construction x female',
       '$\\delta_{2022}$ x Hospitality + Sales x female',
       '$\\delta_{2022}$ x Transport, Storage + IT x female',
       '$\\delta_{2022}$ x Financial + porf. serv. x female',
       '$\\delta_{2022}$ x Education + Health x female',
       '$\\delta_{2022}$ x Other Services x female', '$\\beta_0$']

# reorder_cols = [r'$\beta_0$','female',r'partner tenure (years)',r'$t$',r'$t^{2}$',r'$t$ x female',r'$t^2$ x female',
#                      r'$\delta_{2020}$','$\delta_{2021}$',r'$\delta_{2020}$ x female',
#                      r'$\delta_{2021}$ x female']

def rename_results(df,old_names,new_names,order):
    
    df.rename(columns=dict(zip(old_names,new_names)),inplace='True')
    df = df.reindex(columns=order)
    return df

def pass_regression_to_latex_column(df):

    coefs = df["Coefficient"].copy()
    names = coefs.index.copy()
    N = names.size

    coefs = coefs.apply(lambda x: "{:,.3f}".format(float(x)))
    coefs = coefs.rename(index=(dict(zip(names,np.arange(0,N*2,2)))))

    stds = df['std'].copy()
    stds = stds.apply(lambda x: "({:,.4f})".format(float(x)))
    stds = stds.rename(index=(dict(zip(names,np.arange(1,N*2,2)))))

    final_table = pd.concat([coefs, stds]).sort_index(kind='merge')
    final_table = final_table.rename(index=dict(zip(np.arange(0,N*2,2),names)))
    final_table = final_table.rename(index=dict(zip(np.arange(1,N*2,2),[""]*N)))
    
    return final_table

# %%
all_results[i].T.index
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-213-021e45abc215> in <module>
# ----> 1 all_results[i].T.index
#
# IndexError: list index out of range

# %%
res_names = ['25th pctl','50th pctl','75th pctl']

all_results = [tab_moms_25,tab_moms_50,tab_moms_75]
reorder_cols = new_names_var


for i in range(len(all_results)):
    all_results[i] = rename_results(all_results[i].T,all_results[i].index,new_names_var,new_names_var)
table = pd.DataFrame(pass_regression_to_latex_column(all_results[0].T),columns=[res_names[0],])
for ir,res in enumerate(all_results[1:]):
    col = pass_regression_to_latex_column(res.T)
    table[res_names[ir+1]] = col.values
    
    
for i,reg in enumerate(res_names):
    for var in reorder_cols:
        if all_results[i].loc['p_stat'][var] < 0.1 and all_results[i].loc['p_stat'][var] > 0.05:
            table[reg].loc[var] = r"${}^*$".format(table[reg].loc[var])
        elif all_results[i].loc['p_stat'][var] < 0.05 and all_results[i].loc['p_stat'][var] > 0.01:
            table[reg].loc[var] = r"${}^{{**}}$".format(table[reg].loc[var])
        elif all_results[i].loc['p_stat'][var] < 0.01:
            table[reg].loc[var] = r"${}^{{***}}$".format(table[reg].loc[var])
        else:
            table[reg].loc[var] = r"${}$".format(table[reg].loc[var])
            
N_row = pd.DataFrame([N]*3, index=res_names, columns=['N',]).T
R2_row = pd.DataFrame(r2s, index=res_names, columns=[r'Pseudo $R^2$',]).T
table = pd.concat([table,N_row,R2_row])

# print(table.loc[[r'$\delta_{2020}$','$\delta_{2021}$',r'$\delta_{2020}$ x female',
#                      r'$\delta_{2021}$ x female']].to_latex(escape=False))
print(table)
table.to_latex('./tables/qtregs_ind_3040_full.tex',escape=False)
# Out:
#                                                          25th pctl  \
# $t$                                                 $-0.009^{***}$
#                                                           (0.0009)
# $t$ x female                                         $0.014^{***}$
#                                                           (0.0012)
# unemployment rate x male                             $0.027^{***}$
#                                                           (0.0024)
# unemployment rate x female                           $0.073^{***}$
#                                                           (0.0024)
# Manufactures prim.                                   $2.320^{***}$
#                                                           (0.0834)
# Extractive + energy                                  $2.681^{***}$
#                                                           (0.0442)
# Manufactures sec.                                    $3.073^{***}$
#                                                           (0.0563)
# Construction                                         $0.440^{***}$
#                                                           (0.0237)
# Hospitality + Sales                                  $1.789^{***}$
#                                                           (0.0445)
# Transport, Storage + IT                              $1.551^{***}$
#                                                           (0.0478)
# Financial + porf. serv.                              $2.567^{***}$
#                                                           (0.0553)
# Education + Health                                   $5.113^{***}$
#                                                           (0.0644)
# Other Services                                       $1.499^{***}$
#                                                           (0.0675)
# $\delta_{2020}$ x Agriculture                        $0.511^{***}$
#                                                           (0.1160)
# $\delta_{2020}$ x Manufactures prim.                $-0.465^{***}$
#                                                           (0.1610)
# $\delta_{2020}$ x Extractive + energy                 $0.278^{**}$
#                                                           (0.1303)
# $\delta_{2020}$ x Manufactures sec.                        $0.105$
#                                                           (0.1954)
# $\delta_{2020}$ x Construction                       $0.666^{***}$
#                                                           (0.1084)
# $\delta_{2020}$ x Hospitality + Sales                      $0.154$
#                                                           (0.1435)
# $\delta_{2020}$ x Transport, Storage + IT                  $0.158$
#                                                           (0.1535)
# $\delta_{2020}$ x Financial + porf. serv.            $0.444^{***}$
#                                                           (0.1402)
# $\delta_{2020}$ x Education + Health                       $0.347$
#                                                           (0.4131)
# $\delta_{2020}$ x Other Services                     $1.945^{***}$
#                                                           (0.3324)
# $\delta_{2021}$ x Agriculture                        $0.590^{***}$
#                                                           (0.1290)
# $\delta_{2021}$ x Manufactures prim.                       $0.562$
#                                                           (0.4036)
# $\delta_{2021}$ x Extractive + energy                     $-0.090$
#                                                           (0.2784)
# $\delta_{2021}$ x Manufactures sec.                        $0.295$
#                                                           (0.3760)
# $\delta_{2021}$ x Construction                       $0.900^{***}$
#                                                           (0.1632)
# $\delta_{2021}$ x Hospitality + Sales                $0.912^{***}$
#                                                           (0.1999)
# $\delta_{2021}$ x Transport, Storage + IT                 $-0.183$
#                                                           (0.1645)
# $\delta_{2021}$ x Financial + porf. serv.            $0.523^{***}$
#                                                           (0.1931)
# $\delta_{2021}$ x Education + Health                      $-0.439$
#                                                           (0.3031)
# $\delta_{2021}$ x Other Services                           $1.050$
#                                                           (0.8087)
# $\delta_{2022}$ x Agriculture                        $0.756^{***}$
#                                                           (0.1861)
# $\delta_{2022}$ x Manufactures prim.                       $0.102$
#                                                           (0.5193)
# $\delta_{2022}$ x Extractive + energy                      $0.081$
#                                                           (0.4521)
# $\delta_{2022}$ x Manufactures sec.                  $0.892^{***}$
#                                                           (0.2566)
# $\delta_{2022}$ x Construction                       $1.108^{***}$
#                                                           (0.1352)
# $\delta_{2022}$ x Hospitality + Sales                $1.222^{***}$
#                                                           (0.2003)
# $\delta_{2022}$ x Transport, Storage + IT                 $-0.212$
#                                                           (0.1559)
# $\delta_{2022}$ x Financial + porf. serv.                  $0.194$
#                                                           (0.1937)
# $\delta_{2022}$ x Education + Health                $-1.440^{***}$
#                                                           (0.2615)
# $\delta_{2022}$ x Other Services                      $1.176^{**}$
#                                                           (0.5361)
# Agriculture x female                                $-1.401^{***}$
#                                                           (0.0797)
# Manufactures prim. x female                         $-1.888^{***}$
#                                                           (0.1249)
# Extractive + energy x female                        $-0.887^{***}$
#                                                           (0.1234)
# Manufactures sec. x female                          $-1.362^{***}$
#                                                           (0.1635)
# Construction x female                                      $0.101$
#                                                           (0.0931)
# Hospitality + Sales x female                        $-1.643^{***}$
#                                                           (0.0600)
# Transport, Storage + IT x female                        $-0.206^*$
#                                                           (0.1193)
# Financial + porf. serv. x female                    $-1.532^{***}$
#                                                           (0.0623)
# Education + Health x female                         $-3.552^{***}$
#                                                           (0.0928)
# Other Services x female                             $-2.066^{***}$
#                                                           (0.0688)
# $\delta_{2020}$ x Agriculture x female              $-0.513^{***}$
#                                                           (0.1243)
# $\delta_{2020}$ x Manufactures prim. x female            $0.463^*$
#                                                           (0.2454)
# $\delta_{2020}$ x Extractive + energy x female            $-0.032$
#                                                           (0.5994)
# $\delta_{2020}$ x Manufactures sec. x female            $-1.110^*$
#                                                           (0.6186)
# $\delta_{2020}$ x Construction x female                   $-0.585$
#                                                           (0.4391)
# $\delta_{2020}$ x Hospitality + Sales x female            $-0.096$
#                                                           (0.2419)
# $\delta_{2020}$ x Transport, Storage + IT x female  $-1.143^{***}$
#                                                           (0.3975)
# $\delta_{2020}$ x Financial + porf. serv. x female  $-0.857^{***}$
#                                                           (0.2280)
# $\delta_{2020}$ x Education + Health x female        $-0.880^{**}$
#                                                           (0.4302)
# $\delta_{2020}$ x Other Services x female           $-1.422^{***}$
#                                                           (0.3586)
# $\delta_{2021}$ x Agriculture x female              $-0.636^{***}$
#                                                           (0.1250)
# $\delta_{2021}$ x Manufactures prim. x female             $-0.617$
#                                                           (0.6986)
# $\delta_{2021}$ x Extractive + energy x female            $-0.400$
#                                                           (0.4926)
# $\delta_{2021}$ x Manufactures sec. x female        $-1.453^{***}$
#                                                           (0.4538)
# $\delta_{2021}$ x Construction x female                   $-0.516$
#                                                           (0.3661)
# $\delta_{2021}$ x Hospitality + Sales x female      $-0.839^{***}$
#                                                           (0.2384)
# $\delta_{2021}$ x Transport, Storage + IT x female  $-0.859^{***}$
#                                                           (0.2910)
# $\delta_{2021}$ x Financial + porf. serv. x female  $-1.255^{***}$
#                                                           (0.2491)
# $\delta_{2021}$ x Education + Health x female             $-0.234$
#                                                           (0.3098)
# $\delta_{2021}$ x Other Services x female                 $-0.522$
#                                                           (0.7978)
# $\delta_{2022}$ x Agriculture x female               $-0.582^{**}$
#                                                           (0.2558)
# $\delta_{2022}$ x Manufactures prim. x female             $-0.347$
#                                                           (0.5169)
# $\delta_{2022}$ x Extractive + energy x female       $-1.603^{**}$
#                                                           (0.6747)
# $\delta_{2022}$ x Manufactures sec. x female        $-1.913^{***}$
#                                                           (0.5087)
# $\delta_{2022}$ x Construction x female                   $-0.292$
#                                                           (0.8099)
# $\delta_{2022}$ x Hospitality + Sales x female      $-0.974^{***}$
#                                                           (0.2157)
# $\delta_{2022}$ x Transport, Storage + IT x female  $-1.277^{***}$
#                                                           (0.4132)
# $\delta_{2022}$ x Financial + porf. serv. x female  $-1.230^{***}$
#                                                           (0.2604)
# $\delta_{2022}$ x Education + Health x female        $0.942^{***}$
#                                                           (0.3263)
# $\delta_{2022}$ x Other Services x female               $-1.027^*$
#                                                           (0.5620)
# $\beta_0$                                            $0.168^{***}$
#                                                           (0.0233)
# N                                                          413,371
# Pseudo $R^2$                                                0.0354
#
#                                                          50th pctl  \
# $t$                                                 $-0.004^{***}$
#                                                           (0.0013)
# $t$ x female                                         $0.050^{***}$
#                                                           (0.0018)
# unemployment rate x male                             $0.038^{***}$
#                                                           (0.0035)
# unemployment rate x female                           $0.020^{***}$
#                                                           (0.0046)
# Manufactures prim.                                   $4.488^{***}$
#                                                           (0.1446)
# Extractive + energy                                  $4.758^{***}$
#                                                           (0.0913)
# Manufactures sec.                                    $5.463^{***}$
#                                                           (0.1170)
# Construction                                         $0.524^{***}$
#                                                           (0.1060)
# Hospitality + Sales                                  $3.490^{***}$
#                                                           (0.1162)
# Transport, Storage + IT                              $2.675^{***}$
#                                                           (0.1154)
# Financial + porf. serv.                              $4.206^{***}$
#                                                           (0.1228)
# Education + Health                                   $6.966^{***}$
#                                                           (0.1132)
# Other Services                                       $2.684^{***}$
#                                                           (0.1566)
# $\delta_{2020}$ x Agriculture                           $-0.378^*$
#                                                           (0.2278)
# $\delta_{2020}$ x Manufactures prim.                $-1.563^{***}$
#                                                           (0.3156)
# $\delta_{2020}$ x Extractive + energy                $-0.992^{**}$
#                                                           (0.4478)
# $\delta_{2020}$ x Manufactures sec.                       $-0.507$
#                                                           (0.5439)
# $\delta_{2020}$ x Construction                       $0.765^{***}$
#                                                           (0.2458)
# $\delta_{2020}$ x Hospitality + Sales               $-1.087^{***}$
#                                                           (0.1798)
# $\delta_{2020}$ x Transport, Storage + IT           $-0.939^{***}$
#                                                           (0.3527)
# $\delta_{2020}$ x Financial + porf. serv.                $0.833^*$
#                                                           (0.4998)
# $\delta_{2020}$ x Education + Health                 $1.550^{***}$
#                                                           (0.2651)
# $\delta_{2020}$ x Other Services                         $1.157^*$
#                                                           (0.5937)
# $\delta_{2021}$ x Agriculture                            $0.389^*$
#                                                           (0.2164)
# $\delta_{2021}$ x Manufactures prim.                      $-0.151$
#                                                           (0.5138)
# $\delta_{2021}$ x Extractive + energy               $-1.087^{***}$
#                                                           (0.3418)
# $\delta_{2021}$ x Manufactures sec.                  $-1.074^{**}$
#                                                           (0.5269)
# $\delta_{2021}$ x Construction                        $0.813^{**}$
#                                                           (0.3476)
# $\delta_{2021}$ x Hospitality + Sales                $-0.517^{**}$
#                                                           (0.2425)
# $\delta_{2021}$ x Transport, Storage + IT           $-1.338^{***}$
#                                                           (0.2000)
# $\delta_{2021}$ x Financial + porf. serv.                  $0.351$
#                                                           (0.6117)
# $\delta_{2021}$ x Education + Health                 $1.507^{***}$
#                                                           (0.3489)
# $\delta_{2021}$ x Other Services                     $2.039^{***}$
#                                                           (0.4656)
# $\delta_{2022}$ x Agriculture                        $1.380^{***}$
#                                                           (0.3900)
# $\delta_{2022}$ x Manufactures prim.                       $0.182$
#                                                           (0.3890)
# $\delta_{2022}$ x Extractive + energy                     $-0.337$
#                                                           (0.4764)
# $\delta_{2022}$ x Manufactures sec.                     $-0.833^*$
#                                                           (0.5055)
# $\delta_{2022}$ x Construction                       $1.400^{***}$
#                                                           (0.2774)
# $\delta_{2022}$ x Hospitality + Sales                      $0.139$
#                                                           (0.2500)
# $\delta_{2022}$ x Transport, Storage + IT            $-1.046^{**}$
#                                                           (0.4557)
# $\delta_{2022}$ x Financial + porf. serv.                  $0.090$
#                                                           (0.4887)
# $\delta_{2022}$ x Education + Health                       $0.580$
#                                                           (0.5197)
# $\delta_{2022}$ x Other Services                     $1.736^{***}$
#                                                           (0.5610)
# Agriculture x female                                $-2.591^{***}$
#                                                           (0.1182)
# Manufactures prim. x female                         $-1.915^{***}$
#                                                           (0.2451)
# Extractive + energy x female                        $-1.260^{***}$
#                                                           (0.1495)
# Manufactures sec. x female                          $-1.699^{***}$
#                                                           (0.1048)
# Construction x female                                $1.735^{***}$
#                                                           (0.1893)
# Hospitality + Sales x female                        $-1.750^{***}$
#                                                           (0.1149)
# Transport, Storage + IT x female                           $0.192$
#                                                           (0.1558)
# Financial + porf. serv. x female                    $-1.303^{***}$
#                                                           (0.1065)
# Education + Health x female                         $-3.522^{***}$
#                                                           (0.0738)
# Other Services x female                             $-3.545^{***}$
#                                                           (0.1575)
# $\delta_{2020}$ x Agriculture x female               $-1.193^{**}$
#                                                           (0.5766)
# $\delta_{2020}$ x Manufactures prim. x female              $0.367$
#                                                           (0.6197)
# $\delta_{2020}$ x Extractive + energy x female             $0.416$
#                                                           (0.7245)
# $\delta_{2020}$ x Manufactures sec. x female              $-1.770$
#                                                           (1.4632)
# $\delta_{2020}$ x Construction x female             $-3.019^{***}$
#                                                           (0.5859)
# $\delta_{2020}$ x Hospitality + Sales x female            $-0.359$
#                                                           (0.3077)
# $\delta_{2020}$ x Transport, Storage + IT x female        $-0.442$
#                                                           (0.8094)
# $\delta_{2020}$ x Financial + porf. serv. x female        $-1.083$
#                                                           (0.8047)
# $\delta_{2020}$ x Education + Health x female       $-2.405^{***}$
#                                                           (0.3994)
# $\delta_{2020}$ x Other Services x female           $-1.875^{***}$
#                                                           (0.6120)
# $\delta_{2021}$ x Agriculture x female              $-2.466^{***}$
#                                                           (0.4719)
# $\delta_{2021}$ x Manufactures prim. x female       $-2.538^{***}$
#                                                           (0.6023)
# $\delta_{2021}$ x Extractive + energy x female            $-0.558$
#                                                           (1.2659)
# $\delta_{2021}$ x Manufactures sec. x female        $-3.087^{***}$
#                                                           (0.8214)
# $\delta_{2021}$ x Construction x female              $-3.021^{**}$
#                                                           (1.2901)
# $\delta_{2021}$ x Hospitality + Sales x female      $-1.537^{***}$
#                                                           (0.4166)
# $\delta_{2021}$ x Transport, Storage + IT x female         $0.272$
#                                                           (1.3612)
# $\delta_{2021}$ x Financial + porf. serv. x female  $-3.006^{***}$
#                                                           (0.6990)
# $\delta_{2021}$ x Education + Health x female       $-2.983^{***}$
#                                                           (0.5250)
# $\delta_{2021}$ x Other Services x female           $-2.627^{***}$
#                                                           (0.4681)
# $\delta_{2022}$ x Agriculture x female              $-3.366^{***}$
#                                                           (0.7064)
# $\delta_{2022}$ x Manufactures prim. x female       $-3.061^{***}$
#                                                           (0.8712)
# $\delta_{2022}$ x Extractive + energy x female      $-2.873^{***}$
#                                                           (0.6714)
# $\delta_{2022}$ x Manufactures sec. x female        $-3.508^{***}$
#                                                           (1.0466)
# $\delta_{2022}$ x Construction x female             $-3.071^{***}$
#                                                           (0.8987)
# $\delta_{2022}$ x Hospitality + Sales x female      $-1.759^{***}$
#                                                           (0.3440)
# $\delta_{2022}$ x Transport, Storage + IT x female  $-2.483^{***}$
#                                                           (0.8426)
# $\delta_{2022}$ x Financial + porf. serv. x female  $-3.216^{***}$
#                                                           (0.6862)
# $\delta_{2022}$ x Education + Health x female       $-3.320^{***}$
#                                                           (0.5312)
# $\delta_{2022}$ x Other Services x female           $-3.015^{***}$
#                                                           (0.6399)
# $\beta_0$                                            $2.354^{***}$
#                                                           (0.1016)
# N                                                          413,371
# Pseudo $R^2$                                                0.0466
#
#                                                          75th pctl
# $t$                                                        $0.002$
#                                                           (0.0014)
# $t$ x female                                         $0.033^{***}$
#                                                           (0.0014)
# unemployment rate x male                                  $-0.003$
#                                                           (0.0033)
# unemployment rate x female                          $-0.024^{***}$
#                                                           (0.0041)
# Manufactures prim.                                   $4.129^{***}$
#                                                           (0.2204)
# Extractive + energy                                  $3.897^{***}$
#                                                           (0.1873)
# Manufactures sec.                                    $4.684^{***}$
#                                                           (0.2327)
# Construction                                         $0.591^{***}$
#                                                           (0.1935)
# Hospitality + Sales                                  $3.757^{***}$
#                                                           (0.1945)
# Transport, Storage + IT                              $1.897^{***}$
#                                                           (0.1962)
# Financial + porf. serv.                              $2.925^{***}$
#                                                           (0.1874)
# Education + Health                                   $5.662^{***}$
#                                                           (0.2122)
# Other Services                                       $2.180^{***}$
#                                                           (0.2644)
# $\delta_{2020}$ x Agriculture                              $0.739$
#                                                           (0.5868)
# $\delta_{2020}$ x Manufactures prim.                      $-0.390$
#                                                           (0.3704)
# $\delta_{2020}$ x Extractive + energy                      $0.008$
#                                                           (0.3939)
# $\delta_{2020}$ x Manufactures sec.                        $0.052$
#                                                           (0.2513)
# $\delta_{2020}$ x Construction                       $2.147^{***}$
#                                                           (0.6424)
# $\delta_{2020}$ x Hospitality + Sales                $-0.768^{**}$
#                                                           (0.3884)
# $\delta_{2020}$ x Transport, Storage + IT                  $0.509$
#                                                           (0.4021)
# $\delta_{2020}$ x Financial + porf. serv.            $1.061^{***}$
#                                                           (0.2938)
# $\delta_{2020}$ x Education + Health                     $0.324^*$
#                                                           (0.1959)
# $\delta_{2020}$ x Other Services                           $0.723$
#                                                           (0.5860)
# $\delta_{2021}$ x Agriculture                              $0.729$
#                                                           (1.0101)
# $\delta_{2021}$ x Manufactures prim.                       $0.105$
#                                                           (0.5994)
# $\delta_{2021}$ x Extractive + energy                      $0.504$
#                                                           (0.5226)
# $\delta_{2021}$ x Manufactures sec.                        $0.284$
#                                                           (0.4835)
# $\delta_{2021}$ x Construction                       $3.127^{***}$
#                                                           (1.0183)
# $\delta_{2021}$ x Hospitality + Sales                     $-0.356$
#                                                           (0.5466)
# $\delta_{2021}$ x Transport, Storage + IT             $0.822^{**}$
#                                                           (0.3948)
# $\delta_{2021}$ x Financial + porf. serv.            $1.710^{***}$
#                                                           (0.1399)
# $\delta_{2021}$ x Education + Health                       $0.238$
#                                                           (0.1816)
# $\delta_{2021}$ x Other Services                           $0.554$
#                                                           (0.4877)
# $\delta_{2022}$ x Agriculture                             $-0.292$
#                                                           (0.9355)
# $\delta_{2022}$ x Manufactures prim.                       $0.589$
#                                                           (0.7128)
# $\delta_{2022}$ x Extractive + energy                      $0.813$
#                                                           (0.5387)
# $\delta_{2022}$ x Manufactures sec.                       $-0.223$
#                                                           (0.6435)
# $\delta_{2022}$ x Construction                             $0.118$
#                                                           (0.8331)
# $\delta_{2022}$ x Hospitality + Sales                     $-0.049$
#                                                           (0.3667)
# $\delta_{2022}$ x Transport, Storage + IT                 $-0.189$
#                                                           (0.6514)
# $\delta_{2022}$ x Financial + porf. serv.                 $-0.216$
#                                                           (0.5579)
# $\delta_{2022}$ x Education + Health                     $0.382^*$
#                                                           (0.2302)
# $\delta_{2022}$ x Other Services                           $0.531$
#                                                           (0.7525)
# Agriculture x female                                $-3.288^{***}$
#                                                           (0.3432)
# Manufactures prim. x female                         $-1.183^{***}$
#                                                           (0.1972)
# Extractive + energy x female                        $-1.146^{***}$
#                                                           (0.1047)
# Manufactures sec. x female                          $-1.498^{***}$
#                                                           (0.1791)
# Construction x female                                $1.080^{***}$
#                                                           (0.1528)
# Hospitality + Sales x female                        $-1.884^{***}$
#                                                           (0.1094)
# Transport, Storage + IT x female                         $0.219^*$
#                                                           (0.1218)
# Financial + porf. serv. x female                    $-0.666^{***}$
#                                                           (0.1253)
# Education + Health x female                         $-2.963^{***}$
#                                                           (0.1047)
# Other Services x female                             $-3.234^{***}$
#                                                           (0.2057)
# $\delta_{2020}$ x Agriculture x female                    $-0.701$
#                                                           (1.6745)
# $\delta_{2020}$ x Manufactures prim. x female              $0.149$
#                                                           (0.4803)
# $\delta_{2020}$ x Extractive + energy x female        $0.946^{**}$
#                                                           (0.4569)
# $\delta_{2020}$ x Manufactures sec. x female               $0.576$
#                                                           (0.5354)
# $\delta_{2020}$ x Construction x female                    $0.181$
#                                                           (0.9787)
# $\delta_{2020}$ x Hospitality + Sales x female       $1.350^{***}$
#                                                           (0.4217)
# $\delta_{2020}$ x Transport, Storage + IT x female        $-0.240$
#                                                           (0.5182)
# $\delta_{2020}$ x Financial + porf. serv. x female        $-0.487$
#                                                           (0.4073)
# $\delta_{2020}$ x Education + Health x female             $-0.440$
#                                                           (0.2926)
# $\delta_{2020}$ x Other Services x female                  $0.331$
#                                                           (0.5971)
# $\delta_{2021}$ x Agriculture x female                    $-1.616$
#                                                           (1.1277)
# $\delta_{2021}$ x Manufactures prim. x female       $-3.809^{***}$
#                                                           (0.9212)
# $\delta_{2021}$ x Extractive + energy x female            $-0.629$
#                                                           (0.6045)
# $\delta_{2021}$ x Manufactures sec. x female              $-0.929$
#                                                           (0.8591)
# $\delta_{2021}$ x Construction x female                 $-2.924^*$
#                                                           (1.5973)
# $\delta_{2021}$ x Hospitality + Sales x female            $-0.357$
#                                                           (0.7392)
# $\delta_{2021}$ x Transport, Storage + IT x female        $-0.445$
#                                                           (0.3860)
# $\delta_{2021}$ x Financial + porf. serv. x female  $-2.008^{***}$
#                                                           (0.4267)
# $\delta_{2021}$ x Education + Health x female             $-0.225$
#                                                           (0.2415)
# $\delta_{2021}$ x Other Services x female                 $-0.291$
#                                                           (0.6379)
# $\delta_{2022}$ x Agriculture x female                    $-1.406$
#                                                           (1.7386)
# $\delta_{2022}$ x Manufactures prim. x female       $-3.227^{***}$
#                                                           (1.1970)
# $\delta_{2022}$ x Extractive + energy x female      $-2.363^{***}$
#                                                           (0.6172)
# $\delta_{2022}$ x Manufactures sec. x female              $-1.292$
#                                                           (1.1832)
# $\delta_{2022}$ x Construction x female                    $0.308$
#                                                           (1.5527)
# $\delta_{2022}$ x Hospitality + Sales x female             $0.044$
#                                                           (0.4017)
# $\delta_{2022}$ x Transport, Storage + IT x female        $-1.643$
#                                                           (0.8382)
# $\delta_{2022}$ x Financial + porf. serv. x female        $-1.112$
#                                                           (0.7690)
# $\delta_{2022}$ x Education + Health x female       $-0.983^{***}$
#                                                           (0.2920)
# $\delta_{2022}$ x Other Services x female                 $-1.276$
#                                                           (1.0818)
# $\beta_0$                                            $8.170^{***}$
#                                                           (0.2033)
# N                                                          413,371
# Pseudo $R^2$                                                0.0279
# <ipython-input-214-02d081fca5c6>:33: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   table.to_latex('./tables/qtregs_ind_3040_full.tex',escape=False)

# %%
IoI = []
std_idx = []
for i,idx in enumerate(table.index):
    if str(idx)[:10]=="$\delta_{2":
        if idx.split(' x ')[-1]=='female':
            IoI.append(idx)
            std_idx.append(i+1)
table_dummies_std_f=table.iloc[std_idx,:].copy()
table_dummies_std_f['coefs'] = IoI
table_dummies_std_f.set_index('coefs',inplace=True)
table_dummies_f=table.loc[IoI,:].copy()
table_dummies_f.iloc[:5,:]
# Out:
#                                                      25th pctl  \
# $\delta_{2020}$ x Agriculture x female          $-0.513^{***}$
# $\delta_{2020}$ x Manufactures prim. x female        $0.463^*$
# $\delta_{2020}$ x Extractive + energy x female        $-0.032$
# $\delta_{2020}$ x Manufactures sec. x female        $-1.110^*$
# $\delta_{2020}$ x Construction x female               $-0.585$
#
#                                                      50th pctl     75th pctl
# $\delta_{2020}$ x Agriculture x female           $-1.193^{**}$      $-0.701$
# $\delta_{2020}$ x Manufactures prim. x female          $0.367$       $0.149$
# $\delta_{2020}$ x Extractive + energy x female         $0.416$  $0.946^{**}$
# $\delta_{2020}$ x Manufactures sec. x female          $-1.770$       $0.576$
# $\delta_{2020}$ x Construction x female         $-3.019^{***}$       $0.181$

# %%
IoI_base = []
for ind in IoI:
    IoI_base.append(ind.replace(' x female',''))
tab_dummies=table.loc[IoI_base,:].copy()
print(tab_dummies.tail())
# Out:
#                                                 25th pctl      50th pctl  \
# $\delta_{2022}$ x Hospitality + Sales       $1.222^{***}$        $0.139$
# $\delta_{2022}$ x Transport, Storage + IT        $-0.212$  $-1.046^{**}$
# $\delta_{2022}$ x Financial + porf. serv.         $0.194$        $0.090$
# $\delta_{2022}$ x Education + Health       $-1.440^{***}$        $0.580$
# $\delta_{2022}$ x Other Services             $1.176^{**}$  $1.736^{***}$
#
#                                            75th pctl
# $\delta_{2022}$ x Hospitality + Sales       $-0.049$
# $\delta_{2022}$ x Transport, Storage + IT   $-0.189$
# $\delta_{2022}$ x Financial + porf. serv.   $-0.216$
# $\delta_{2022}$ x Education + Health       $0.382^*$
# $\delta_{2022}$ x Other Services             $0.531$

# %%
IoI_20,IoI_21,IoI_22 = [], [], []
std_idx_20, std_idx_21, std_idx_22 = [], [], []
for i,idx in enumerate(table.index):
    if str(idx)[:13]=="$\delta_{2020":
        if idx.split(' x ')[-1]=='female':
            IoI_20.append(idx)
            std_idx_20.append(i+1)
    elif str(idx)[:13]=="$\delta_{2021":
        if idx.split(' x ')[-1]=='female':
            IoI_21.append(idx)
            std_idx_21.append(i+1)
    elif str(idx)[:13]=="$\delta_{2022":
        if idx.split(' x ')[-1]=='female':
            IoI_22.append(idx)
            std_idx_22.append(i+1)

table_dummies_std_f_20,table_dummies_std_f_21, table_dummies_std_f_22 = table.iloc[std_idx_20,:].copy(),table.iloc[std_idx_21,:].copy(),table.iloc[std_idx_22,:].copy()
table_dummies_f_20,table_dummies_f_21, table_dummies_f_22 = table.loc[IoI_20,:].copy(),table.loc[IoI_21,:].copy(),table.loc[IoI_22,:].copy()

# IoI_20[1] = IoI_20[1].replace('Manifactures','Manufactures')
# IoI_20[3] = IoI_20[3].replace('manifuctures','Manufactures')

table_dummies_std_f_20['coefs'] = IoI_20
table_dummies_std_f_21['coefs'] = IoI_21
table_dummies_std_f_22['coefs'] = IoI_22
table_dummies_std_f_20.set_index('coefs',inplace=True)
table_dummies_std_f_21.set_index('coefs',inplace=True)
table_dummies_std_f_22.set_index('coefs',inplace=True)

all_data = [table_dummies_f_20.T,table_dummies_f_21.T,table_dummies_f_22.T]
all_stds = [table_dummies_std_f_20.T,table_dummies_std_f_21.T,table_dummies_std_f_22.T]

One_table = {}
for i in range(3):
    coefs, stds = all_data[i], all_stds[i]
    cols= coefs.keys()
    New_table = coefs[cols[0]]
    New_table = pd.concat((New_table.rename(cols[0][18:]),stds[cols[0]].rename(cols[0][18:]+'_std')),axis=1)
    for name in cols[1:]:
        New_table = pd.concat((New_table,coefs[name].rename(name[18:]),stds[name].rename(name[18:]+'_std')),axis=1)
    
    One_table[2020+i] = New_table.T.copy()
    
Final_table = pd.concat((One_table[2020]['25th pctl'].rename("2020"),
           One_table[2021]['25th pctl'].rename("2021"),
          One_table[2022]['25th pctl'].rename("2022")),axis=1)

for ind in Final_table.index[1::2]:
    Final_table.rename({ind:""}, inplace=True)
Final_table.replace({np.nan:'--'}, inplace=True)

Final_table2 = pd.concat((One_table[2020]['50th pctl'].rename("2020"),
           One_table[2021]['50th pctl'].rename("2021"),
          One_table[2022]['50th pctl'].rename("2022")),axis=1)

for ind in Final_table2.index[1::2]:
    Final_table2.rename({ind:""}, inplace=True)
Final_table2.replace({np.nan:'--'}, inplace=True)

Final_table3 = pd.concat((One_table[2020]['75th pctl'].rename("2020"),
           One_table[2021]['75th pctl'].rename("2021"),
          One_table[2022]['75th pctl'].rename("2022")),axis=1)

for ind in Final_table3.index[1::2]:
    Final_table3.rename({ind:""}, inplace=True)
Final_table3.replace({np.nan:'--'}, inplace=True)

Final_final_table = pd.concat((Final_table,Final_table2,Final_table3),axis=1,keys=['25th percentile','50th percentile','75th percentile'])
Final_final_table.loc["N",:] = table.loc['N'][0]
print(Final_final_table.to_latex(escape=False))
Final_final_table.to_latex('./tables/qtregs_ind_3040_text.tex',escape=False)
# Out:
# \begin{tabular}{llllllllll}
# \toprule
# {} & \multicolumn{3}{l}{25th percentile} & \multicolumn{3}{l}{50th percentile} & \multicolumn{3}{l}{75th percentile} \\
# {} &            2020 &            2021 &            2022 &            2020 &            2021 &            2022 &            2020 &            2021 &            2022 \\
# \midrule
# Agriculture x female             &  $-0.513^{***}$ &  $-0.636^{***}$ &   $-0.582^{**}$ &   $-1.193^{**}$ &  $-2.466^{***}$ &  $-3.366^{***}$ &        $-0.701$ &        $-1.616$ &        $-1.406$ \\
#                                  &        (0.1243) &        (0.1250) &        (0.2558) &        (0.5766) &        (0.4719) &        (0.7064) &        (1.6745) &        (1.1277) &        (1.7386) \\
# Manufactures prim. x female      &       $0.463^*$ &        $-0.617$ &        $-0.347$ &         $0.367$ &  $-2.538^{***}$ &  $-3.061^{***}$ &         $0.149$ &  $-3.809^{***}$ &  $-3.227^{***}$ \\
#                                  &        (0.2454) &        (0.6986) &        (0.5169) &        (0.6197) &        (0.6023) &        (0.8712) &        (0.4803) &        (0.9212) &        (1.1970) \\
# Extractive + energy x female     &        $-0.032$ &        $-0.400$ &   $-1.603^{**}$ &         $0.416$ &        $-0.558$ &  $-2.873^{***}$ &    $0.946^{**}$ &        $-0.629$ &  $-2.363^{***}$ \\
#                                  &        (0.5994) &        (0.4926) &        (0.6747) &        (0.7245) &        (1.2659) &        (0.6714) &        (0.4569) &        (0.6045) &        (0.6172) \\
# Manufactures sec. x female       &      $-1.110^*$ &  $-1.453^{***}$ &  $-1.913^{***}$ &        $-1.770$ &  $-3.087^{***}$ &  $-3.508^{***}$ &         $0.576$ &        $-0.929$ &        $-1.292$ \\
#                                  &        (0.6186) &        (0.4538) &        (0.5087) &        (1.4632) &        (0.8214) &        (1.0466) &        (0.5354) &        (0.8591) &        (1.1832) \\
# Construction x female            &        $-0.585$ &        $-0.516$ &        $-0.292$ &  $-3.019^{***}$ &   $-3.021^{**}$ &  $-3.071^{***}$ &         $0.181$ &      $-2.924^*$ &         $0.308$ \\
#                                  &        (0.4391) &        (0.3661) &        (0.8099) &        (0.5859) &        (1.2901) &        (0.8987) &        (0.9787) &        (1.5973) &        (1.5527) \\
# Hospitality + Sales x female     &        $-0.096$ &  $-0.839^{***}$ &  $-0.974^{***}$ &        $-0.359$ &  $-1.537^{***}$ &  $-1.759^{***}$ &   $1.350^{***}$ &        $-0.357$ &         $0.044$ \\
#                                  &        (0.2419) &        (0.2384) &        (0.2157) &        (0.3077) &        (0.4166) &        (0.3440) &        (0.4217) &        (0.7392) &        (0.4017) \\
# Transport, Storage + IT x female &  $-1.143^{***}$ &  $-0.859^{***}$ &  $-1.277^{***}$ &        $-0.442$ &         $0.272$ &  $-2.483^{***}$ &        $-0.240$ &        $-0.445$ &        $-1.643$ \\
#                                  &        (0.3975) &        (0.2910) &        (0.4132) &        (0.8094) &        (1.3612) &        (0.8426) &        (0.5182) &        (0.3860) &        (0.8382) \\
# Financial + porf. serv. x female &  $-0.857^{***}$ &  $-1.255^{***}$ &  $-1.230^{***}$ &        $-1.083$ &  $-3.006^{***}$ &  $-3.216^{***}$ &        $-0.487$ &  $-2.008^{***}$ &        $-1.112$ \\
#                                  &        (0.2280) &        (0.2491) &        (0.2604) &        (0.8047) &        (0.6990) &        (0.6862) &        (0.4073) &        (0.4267) &        (0.7690) \\
# Education + Health x female      &   $-0.880^{**}$ &        $-0.234$ &   $0.942^{***}$ &  $-2.405^{***}$ &  $-2.983^{***}$ &  $-3.320^{***}$ &        $-0.440$ &        $-0.225$ &  $-0.983^{***}$ \\
#                                  &        (0.4302) &        (0.3098) &        (0.3263) &        (0.3994) &        (0.5250) &        (0.5312) &        (0.2926) &        (0.2415) &        (0.2920) \\
# Other Services x female          &  $-1.422^{***}$ &        $-0.522$ &      $-1.027^*$ &  $-1.875^{***}$ &  $-2.627^{***}$ &  $-3.015^{***}$ &         $0.331$ &        $-0.291$ &        $-1.276$ \\
#                                  &        (0.3586) &        (0.7978) &        (0.5620) &        (0.6120) &        (0.4681) &        (0.6399) &        (0.5971) &        (0.6379) &        (1.0818) \\
# N                                &         413,371 &         413,371 &         413,371 &         413,371 &         413,371 &         413,371 &         413,371 &         413,371 &         413,371 \\
# \bottomrule
# \end{tabular}
# <ipython-input-217-36637e6cdbd0>:70: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(Final_final_table.to_latex(escape=False))
# <ipython-input-217-36637e6cdbd0>:71: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   Final_final_table.to_latex('./tables/qtregs_ind_3040_text.tex',escape=False)

# %%
IoI_20,IoI_21,IoI_22 = [], [], []
std_idx_20, std_idx_21, std_idx_22 = [], [], []
for i,idx in enumerate(table.index):
    if str(idx)[:13]=="$\delta_{2020":
        if idx.split(' x ')[-1]!='female':
            IoI_20.append(idx)
            std_idx_20.append(i+1)
    elif str(idx)[:13]=="$\delta_{2021":
        if idx.split(' x ')[-1]!='female':
            IoI_21.append(idx)
            std_idx_21.append(i+1)
    elif str(idx)[:13]=="$\delta_{2022":
        if idx.split(' x ')[-1]!='female':
            IoI_22.append(idx)
            std_idx_22.append(i+1)
table_dummies_std_f_20,table_dummies_std_f_21, table_dummies_std_f_22 = table.iloc[std_idx_20,:].copy(),table.iloc[std_idx_21,:].copy(),table.iloc[std_idx_22,:].copy()
table_dummies_f_20,table_dummies_f_21, table_dummies_f_22 = table.loc[IoI_20,:].copy(),table.loc[IoI_21,:].copy(),table.loc[IoI_22,:].copy()

# IoI_20[1] = IoI_20[1].replace('Manifactures','Manufactures')
# IoI_20[3] = IoI_20[3].replace('manifuctures','Manufactures')

table_dummies_std_f_20['coefs'] = IoI_20
table_dummies_std_f_21['coefs'] = IoI_21
table_dummies_std_f_22['coefs'] = IoI_22
table_dummies_std_f_20.set_index('coefs',inplace=True)
table_dummies_std_f_21.set_index('coefs',inplace=True)
table_dummies_std_f_22.set_index('coefs',inplace=True)

all_data = [table_dummies_f_20.T,table_dummies_f_21.T,table_dummies_f_22.T]
all_stds = [table_dummies_std_f_20.T,table_dummies_std_f_21.T,table_dummies_std_f_22.T]

One_table = {}
for i in range(3):
    coefs, stds = all_data[i], all_stds[i]
    cols= coefs.keys()
#     print(cols)
    New_table = coefs[cols[0]]
    New_table = pd.concat((New_table.rename(cols[0][18:]),stds[cols[0]].rename(cols[0][18:]+'_std')),axis=1)
    for name in cols[1:]:
        New_table = pd.concat((New_table,coefs[name].rename(name[18:]),stds[name].rename(name[18:]+'_std')),axis=1)
        
    One_table[2020+i] = New_table.T.copy()
    
Final_table = pd.concat((One_table[2020]['25th pctl'].rename("2020"),
           One_table[2021]['25th pctl'].rename("2021"),
          One_table[2022]['25th pctl'].rename("2022")),axis=1)

for ind in Final_table.index[1::2]:
    Final_table.rename({ind:""}, inplace=True)
Final_table.replace({np.nan:'--'}, inplace=True)

Final_table2 = pd.concat((One_table[2020]['50th pctl'].rename("2020"),
           One_table[2021]['50th pctl'].rename("2021"),
          One_table[2022]['50th pctl'].rename("2022")),axis=1)

for ind in Final_table2.index[1::2]:
    Final_table2.rename({ind:""}, inplace=True)
Final_table2.replace({np.nan:'--'}, inplace=True)

Final_table3 = pd.concat((One_table[2020]['75th pctl'].rename("2020"),
           One_table[2021]['75th pctl'].rename("2021"),
          One_table[2022]['75th pctl'].rename("2022")),axis=1)

for ind in Final_table3.index[1::2]:
    Final_table3.rename({ind:""}, inplace=True)
Final_table3.replace({np.nan:'--'}, inplace=True)

Final_final_table_b = pd.concat((Final_table,Final_table2,Final_table3),axis=1,keys=['25th percentile','50th percentile','75th percentile'])
# print(Final_final_table_b.to_latex(escape=False))

Final_final_final_table = pd.concat((Final_final_table_b,Final_final_table))
Final_final_final_table.to_latex('./tables/qtregs_ind_3040_full_part2.tex',escape=False,column_format='l|ccc|ccc|ccc|')
Final_final_final_table
# Out:
# <ipython-input-246-53d3ac33913d>:72: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   Final_final_final_table.to_latex('./tables/qtregs_ind_3040_full_part2.tex',escape=False,column_format='l|ccc|ccc|ccc|')
#                                  25th percentile                  \
#                                             2020            2021
# Agriculture                        $0.511^{***}$   $0.590^{***}$
#                                         (0.1160)        (0.1290)
# Manufactures prim.                $-0.465^{***}$         $0.562$
#                                         (0.1610)        (0.4036)
# Extractive + energy                 $0.278^{**}$        $-0.090$
#                                         (0.1303)        (0.2784)
# Manufactures sec.                        $0.105$         $0.295$
#                                         (0.1954)        (0.3760)
# Construction                       $0.666^{***}$   $0.900^{***}$
#                                         (0.1084)        (0.1632)
# Hospitality + Sales                      $0.154$   $0.912^{***}$
#                                         (0.1435)        (0.1999)
# Transport, Storage + IT                  $0.158$        $-0.183$
#                                         (0.1535)        (0.1645)
# Financial + porf. serv.            $0.444^{***}$   $0.523^{***}$
#                                         (0.1402)        (0.1931)
# Education + Health                       $0.347$        $-0.439$
#                                         (0.4131)        (0.3031)
# Other Services                     $1.945^{***}$         $1.050$
#                                         (0.3324)        (0.8087)
# Agriculture x female              $-0.513^{***}$  $-0.636^{***}$
#                                         (0.1243)        (0.1250)
# Manufactures prim. x female            $0.463^*$        $-0.617$
#                                         (0.2454)        (0.6986)
# Extractive + energy x female            $-0.032$        $-0.400$
#                                         (0.5994)        (0.4926)
# Manufactures sec. x female            $-1.110^*$  $-1.453^{***}$
#                                         (0.6186)        (0.4538)
# Construction x female                   $-0.585$        $-0.516$
#                                         (0.4391)        (0.3661)
# Hospitality + Sales x female            $-0.096$  $-0.839^{***}$
#                                         (0.2419)        (0.2384)
# Transport, Storage + IT x female  $-1.143^{***}$  $-0.859^{***}$
#                                         (0.3975)        (0.2910)
# Financial + porf. serv. x female  $-0.857^{***}$  $-1.255^{***}$
#                                         (0.2280)        (0.2491)
# Education + Health x female        $-0.880^{**}$        $-0.234$
#                                         (0.4302)        (0.3098)
# Other Services x female           $-1.422^{***}$        $-0.522$
#                                         (0.3586)        (0.7978)
# N                                        413,371         413,371
#
#                                                  50th percentile  \
#                                             2022            2020
# Agriculture                        $0.756^{***}$      $-0.378^*$
#                                         (0.1861)        (0.2278)
# Manufactures prim.                       $0.102$  $-1.563^{***}$
#                                         (0.5193)        (0.3156)
# Extractive + energy                      $0.081$   $-0.992^{**}$
#                                         (0.4521)        (0.4478)
# Manufactures sec.                  $0.892^{***}$        $-0.507$
#                                         (0.2566)        (0.5439)
# Construction                       $1.108^{***}$   $0.765^{***}$
#                                         (0.1352)        (0.2458)
# Hospitality + Sales                $1.222^{***}$  $-1.087^{***}$
#                                         (0.2003)        (0.1798)
# Transport, Storage + IT                 $-0.212$  $-0.939^{***}$
#                                         (0.1559)        (0.3527)
# Financial + porf. serv.                  $0.194$       $0.833^*$
#                                         (0.1937)        (0.4998)
# Education + Health                $-1.440^{***}$   $1.550^{***}$
#                                         (0.2615)        (0.2651)
# Other Services                      $1.176^{**}$       $1.157^*$
#                                         (0.5361)        (0.5937)
# Agriculture x female               $-0.582^{**}$   $-1.193^{**}$
#                                         (0.2558)        (0.5766)
# Manufactures prim. x female             $-0.347$         $0.367$
#                                         (0.5169)        (0.6197)
# Extractive + energy x female       $-1.603^{**}$         $0.416$
#                                         (0.6747)        (0.7245)
# Manufactures sec. x female        $-1.913^{***}$        $-1.770$
#                                         (0.5087)        (1.4632)
# Construction x female                   $-0.292$  $-3.019^{***}$
#                                         (0.8099)        (0.5859)
# Hospitality + Sales x female      $-0.974^{***}$        $-0.359$
#                                         (0.2157)        (0.3077)
# Transport, Storage + IT x female  $-1.277^{***}$        $-0.442$
#                                         (0.4132)        (0.8094)
# Financial + porf. serv. x female  $-1.230^{***}$        $-1.083$
#                                         (0.2604)        (0.8047)
# Education + Health x female        $0.942^{***}$  $-2.405^{***}$
#                                         (0.3263)        (0.3994)
# Other Services x female               $-1.027^*$  $-1.875^{***}$
#                                         (0.5620)        (0.6120)
# N                                        413,371         413,371
#
#                                                                   \
#                                             2021            2022
# Agriculture                            $0.389^*$   $1.380^{***}$
#                                         (0.2164)        (0.3900)
# Manufactures prim.                      $-0.151$         $0.182$
#                                         (0.5138)        (0.3890)
# Extractive + energy               $-1.087^{***}$        $-0.337$
#                                         (0.3418)        (0.4764)
# Manufactures sec.                  $-1.074^{**}$      $-0.833^*$
#                                         (0.5269)        (0.5055)
# Construction                        $0.813^{**}$   $1.400^{***}$
#                                         (0.3476)        (0.2774)
# Hospitality + Sales                $-0.517^{**}$         $0.139$
#                                         (0.2425)        (0.2500)
# Transport, Storage + IT           $-1.338^{***}$   $-1.046^{**}$
#                                         (0.2000)        (0.4557)
# Financial + porf. serv.                  $0.351$         $0.090$
#                                         (0.6117)        (0.4887)
# Education + Health                 $1.507^{***}$         $0.580$
#                                         (0.3489)        (0.5197)
# Other Services                     $2.039^{***}$   $1.736^{***}$
#                                         (0.4656)        (0.5610)
# Agriculture x female              $-2.466^{***}$  $-3.366^{***}$
#                                         (0.4719)        (0.7064)
# Manufactures prim. x female       $-2.538^{***}$  $-3.061^{***}$
#                                         (0.6023)        (0.8712)
# Extractive + energy x female            $-0.558$  $-2.873^{***}$
#                                         (1.2659)        (0.6714)
# Manufactures sec. x female        $-3.087^{***}$  $-3.508^{***}$
#                                         (0.8214)        (1.0466)
# Construction x female              $-3.021^{**}$  $-3.071^{***}$
#                                         (1.2901)        (0.8987)
# Hospitality + Sales x female      $-1.537^{***}$  $-1.759^{***}$
#                                         (0.4166)        (0.3440)
# Transport, Storage + IT x female         $0.272$  $-2.483^{***}$
#                                         (1.3612)        (0.8426)
# Financial + porf. serv. x female  $-3.006^{***}$  $-3.216^{***}$
#                                         (0.6990)        (0.6862)
# Education + Health x female       $-2.983^{***}$  $-3.320^{***}$
#                                         (0.5250)        (0.5312)
# Other Services x female           $-2.627^{***}$  $-3.015^{***}$
#                                         (0.4681)        (0.6399)
# N                                        413,371         413,371
#
#                                  75th percentile                  \
#                                             2020            2021
# Agriculture                              $0.739$         $0.729$
#                                         (0.5868)        (1.0101)
# Manufactures prim.                      $-0.390$         $0.105$
#                                         (0.3704)        (0.5994)
# Extractive + energy                      $0.008$         $0.504$
#                                         (0.3939)        (0.5226)
# Manufactures sec.                        $0.052$         $0.284$
#                                         (0.2513)        (0.4835)
# Construction                       $2.147^{***}$   $3.127^{***}$
#                                         (0.6424)        (1.0183)
# Hospitality + Sales                $-0.768^{**}$        $-0.356$
#                                         (0.3884)        (0.5466)
# Transport, Storage + IT                  $0.509$    $0.822^{**}$
#                                         (0.4021)        (0.3948)
# Financial + porf. serv.            $1.061^{***}$   $1.710^{***}$
#                                         (0.2938)        (0.1399)
# Education + Health                     $0.324^*$         $0.238$
#                                         (0.1959)        (0.1816)
# Other Services                           $0.723$         $0.554$
#                                         (0.5860)        (0.4877)
# Agriculture x female                    $-0.701$        $-1.616$
#                                         (1.6745)        (1.1277)
# Manufactures prim. x female              $0.149$  $-3.809^{***}$
#                                         (0.4803)        (0.9212)
# Extractive + energy x female        $0.946^{**}$        $-0.629$
#                                         (0.4569)        (0.6045)
# Manufactures sec. x female               $0.576$        $-0.929$
#                                         (0.5354)        (0.8591)
# Construction x female                    $0.181$      $-2.924^*$
#                                         (0.9787)        (1.5973)
# Hospitality + Sales x female       $1.350^{***}$        $-0.357$
#                                         (0.4217)        (0.7392)
# Transport, Storage + IT x female        $-0.240$        $-0.445$
#                                         (0.5182)        (0.3860)
# Financial + porf. serv. x female        $-0.487$  $-2.008^{***}$
#                                         (0.4073)        (0.4267)
# Education + Health x female             $-0.440$        $-0.225$
#                                         (0.2926)        (0.2415)
# Other Services x female                  $0.331$        $-0.291$
#                                         (0.5971)        (0.6379)
# N                                        413,371         413,371
#
#
#                                             2022
# Agriculture                             $-0.292$
#                                         (0.9355)
# Manufactures prim.                       $0.589$
#                                         (0.7128)
# Extractive + energy                      $0.813$
#                                         (0.5387)
# Manufactures sec.                       $-0.223$
#                                         (0.6435)
# Construction                             $0.118$
#                                         (0.8331)
# Hospitality + Sales                     $-0.049$
#                                         (0.3667)
# Transport, Storage + IT                 $-0.189$
#                                         (0.6514)
# Financial + porf. serv.                 $-0.216$
#                                         (0.5579)
# Education + Health                     $0.382^*$
#                                         (0.2302)
# Other Services                           $0.531$
#                                         (0.7525)
# Agriculture x female                    $-1.406$
#                                         (1.7386)
# Manufactures prim. x female       $-3.227^{***}$
#                                         (1.1970)
# Extractive + energy x female      $-2.363^{***}$
#                                         (0.6172)
# Manufactures sec. x female              $-1.292$
#                                         (1.1832)
# Construction x female                    $0.308$
#                                         (1.5527)
# Hospitality + Sales x female             $0.044$
#                                         (0.4017)
# Transport, Storage + IT x female        $-1.643$
#                                         (0.8382)
# Financial + porf. serv. x female        $-1.112$
#                                         (0.7690)
# Education + Health x female       $-0.983^{***}$
#                                         (0.2920)
# Other Services x female                 $-1.276$
#                                         (1.0818)
# N                                        413,371

# %%
IoI_rest = []
std_idx_rest = []
for i,idx in enumerate(table.index):
    if str(idx)[:12]!="$\delta_{202" and str(idx)!='':
        
        IoI_rest.append(idx)
        if str(idx) in ['N',"Pseudo $R^2$"]:
            pass
        else:
            std_idx_rest.append(i+1)

table_rest_std_f_20 = table.iloc[std_idx_rest,:].copy()
table_rest_f_20 = table.loc[IoI_rest,:].copy()

table_rest_f_20 = table_rest_f_20.T

table_rest_std_f_20['coefs'] = IoI_rest[:-2]
table_rest_std_f_20.set_index('coefs',inplace=True)
table_rest_std_f_20 = table_rest_std_f_20.T

cols= table_rest_f_20.keys()[:-2]
# print(cols)
New_table = table_rest_f_20[cols[0]]
New_table = pd.concat((New_table.rename(cols[0]),table_rest_std_f_20[cols[0]].rename(cols[0]+'_std')),axis=1)
for name in cols[1:]:
    New_table = pd.concat((New_table,table_rest_f_20[name].rename(name),
                         table_rest_std_f_20[name].rename(name+'_std')),axis=1)


Final_table =  New_table.T.copy()

for ind in Final_table.index[1::2]:
    Final_table.rename({ind:""}, inplace=True)
Final_table.replace({np.nan:'--'}, inplace=True)
Final_table.loc['N',:] = table.loc['N',:]
Final_table.loc["Pseudo $R^2$",:] = table.loc["Pseudo $R^2$",:]
Final_table.to_latex('./tables/qtregs_ind_3040_full_part1.tex',escape=False,column_format='l|ccc|')
Final_table
# Out:
# <ipython-input-245-c2dd6da34848>:37: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   Final_table.to_latex('./tables/qtregs_ind_3040_full_part1.tex',escape=False,column_format='l|ccc|')
#                                        25th pctl       50th pctl  \
# $t$                               $-0.009^{***}$  $-0.004^{***}$
#                                         (0.0009)        (0.0013)
# $t$ x female                       $0.014^{***}$   $0.050^{***}$
#                                         (0.0012)        (0.0018)
# unemployment rate x male           $0.027^{***}$   $0.038^{***}$
#                                         (0.0024)        (0.0035)
# unemployment rate x female         $0.073^{***}$   $0.020^{***}$
#                                         (0.0024)        (0.0046)
# Manufactures prim.                 $2.320^{***}$   $4.488^{***}$
#                                         (0.0834)        (0.1446)
# Extractive + energy                $2.681^{***}$   $4.758^{***}$
#                                         (0.0442)        (0.0913)
# Manufactures sec.                  $3.073^{***}$   $5.463^{***}$
#                                         (0.0563)        (0.1170)
# Construction                       $0.440^{***}$   $0.524^{***}$
#                                         (0.0237)        (0.1060)
# Hospitality + Sales                $1.789^{***}$   $3.490^{***}$
#                                         (0.0445)        (0.1162)
# Transport, Storage + IT            $1.551^{***}$   $2.675^{***}$
#                                         (0.0478)        (0.1154)
# Financial + porf. serv.            $2.567^{***}$   $4.206^{***}$
#                                         (0.0553)        (0.1228)
# Education + Health                 $5.113^{***}$   $6.966^{***}$
#                                         (0.0644)        (0.1132)
# Other Services                     $1.499^{***}$   $2.684^{***}$
#                                         (0.0675)        (0.1566)
# Agriculture x female              $-1.401^{***}$  $-2.591^{***}$
#                                         (0.0797)        (0.1182)
# Manufactures prim. x female       $-1.888^{***}$  $-1.915^{***}$
#                                         (0.1249)        (0.2451)
# Extractive + energy x female      $-0.887^{***}$  $-1.260^{***}$
#                                         (0.1234)        (0.1495)
# Manufactures sec. x female        $-1.362^{***}$  $-1.699^{***}$
#                                         (0.1635)        (0.1048)
# Construction x female                    $0.101$   $1.735^{***}$
#                                         (0.0931)        (0.1893)
# Hospitality + Sales x female      $-1.643^{***}$  $-1.750^{***}$
#                                         (0.0600)        (0.1149)
# Transport, Storage + IT x female      $-0.206^*$         $0.192$
#                                         (0.1193)        (0.1558)
# Financial + porf. serv. x female  $-1.532^{***}$  $-1.303^{***}$
#                                         (0.0623)        (0.1065)
# Education + Health x female       $-3.552^{***}$  $-3.522^{***}$
#                                         (0.0928)        (0.0738)
# Other Services x female           $-2.066^{***}$  $-3.545^{***}$
#                                         (0.0688)        (0.1575)
# $\beta_0$                          $0.168^{***}$   $2.354^{***}$
#                                         (0.0233)        (0.1016)
# N                                        413,371         413,371
# Pseudo $R^2$                              0.0354          0.0466
#
#                                        75th pctl
# $t$                                      $0.002$
#                                         (0.0014)
# $t$ x female                       $0.033^{***}$
#                                         (0.0014)
# unemployment rate x male                $-0.003$
#                                         (0.0033)
# unemployment rate x female        $-0.024^{***}$
#                                         (0.0041)
# Manufactures prim.                 $4.129^{***}$
#                                         (0.2204)
# Extractive + energy                $3.897^{***}$
#                                         (0.1873)
# Manufactures sec.                  $4.684^{***}$
#                                         (0.2327)
# Construction                       $0.591^{***}$
#                                         (0.1935)
# Hospitality + Sales                $3.757^{***}$
#                                         (0.1945)
# Transport, Storage + IT            $1.897^{***}$
#                                         (0.1962)
# Financial + porf. serv.            $2.925^{***}$
#                                         (0.1874)
# Education + Health                 $5.662^{***}$
#                                         (0.2122)
# Other Services                     $2.180^{***}$
#                                         (0.2644)
# Agriculture x female              $-3.288^{***}$
#                                         (0.3432)
# Manufactures prim. x female       $-1.183^{***}$
#                                         (0.1972)
# Extractive + energy x female      $-1.146^{***}$
#                                         (0.1047)
# Manufactures sec. x female        $-1.498^{***}$
#                                         (0.1791)
# Construction x female              $1.080^{***}$
#                                         (0.1528)
# Hospitality + Sales x female      $-1.884^{***}$
#                                         (0.1094)
# Transport, Storage + IT x female       $0.219^*$
#                                         (0.1218)
# Financial + porf. serv. x female  $-0.666^{***}$
#                                         (0.1253)
# Education + Health x female       $-2.963^{***}$
#                                         (0.1047)
# Other Services x female           $-3.234^{***}$
#                                         (0.2057)
# $\beta_0$                          $8.170^{***}$
#                                         (0.2033)
# N                                        413,371
# Pseudo $R^2$                              0.0279

# %% [markdown]
# ## Figure 11 and co

# %%
IoI_base = []
for ind in IoI:
    IoI_base.append(ind.replace(' x female',''))
table_dummies=table.loc[IoI_base,:].copy()
table_dummies.head()
# Out:
#                                             25th pctl       50th pctl  \
# $\delta_{2020}$ x Agriculture           $0.511^{***}$      $-0.378^*$
# $\delta_{2020}$ x Manufactures prim.   $-0.465^{***}$  $-1.563^{***}$
# $\delta_{2020}$ x Extractive + energy    $0.278^{**}$   $-0.992^{**}$
# $\delta_{2020}$ x Manufactures sec.           $0.105$        $-0.507$
# $\delta_{2020}$ x Construction          $0.666^{***}$   $0.765^{***}$
#
#                                            75th pctl
# $\delta_{2020}$ x Agriculture                $0.739$
# $\delta_{2020}$ x Manufactures prim.        $-0.390$
# $\delta_{2020}$ x Extractive + energy        $0.008$
# $\delta_{2020}$ x Manufactures sec.          $0.052$
# $\delta_{2020}$ x Construction         $2.147^{***}$

# %%
def stars_to_sig(thing):
    if thing[-5:] == '***}$':         
        res = 0.01
    elif thing[-5:] == '{**}$':
        res = 0.05
    elif thing[-3:] == '^*$':
        res = 0.1
    else:
        res = 1.0
    return res

# %%
pctiles = [25,50,75]

for p in pctiles:
    sig_list = []
    sig_list2 = []
    for name in IoI:
        thing = table_dummies_f.loc[name,'{}th pctl'.format(p)]
        sig_list.append(stars_to_sig(thing))
    for name in IoI_base:
        thing2 = table_dummies.loc[name,'{}th pctl'.format(p)]
        sig_list2.append(stars_to_sig(thing2))
    table_dummies_f['sig {}'.format(p)] = np.array(sig_list)
    table_dummies['sig {}'.format(p)] = np.array(sig_list2)

# %%
for p in pctiles:
    num_list,num_list2 = [],[]
    for name in IoI:
        thing = table_dummies_f.loc[name,'{}th pctl'.format(p)]
        thing = thing.replace('*','').replace('{','').replace('}','').replace('$','').replace('^','')
        num_list.append(thing)
    for name in IoI_base:
        thing2 = table_dummies.loc[name,'{}th pctl'.format(p)]
        thing2 = thing2.replace('*','').replace('{','').replace('}','').replace('$','').replace('^','')
        num_list2.append(thing2)
    table_dummies_f.loc[:,'{}th pctl'.format(p)] = num_list
    table_dummies.loc[:,'{}th pctl'.format(p)] = num_list2

# %%
indust_list = []
for name in IoI:
    indust_list.append(name.split(' x ')[1])
dic_ind_translate = dict(zip(indust_list[:10],industry_dict.values()))

all_ind_dums = []
all_year_dums = []
for ind in table_dummies_f.index:
    all_ind_dums.append(dic_ind_translate[ind.split(' x ')[1]])
    all_year_dums.append(int(ind.split(' x ')[0].replace('$\\delta_{','').replace("}$","")))
table_dummies_f['year'] = all_year_dums
table_dummies_f['ind'] = all_ind_dums

all_ind_dums2 = []
all_year_dums2 = []
for ind in table_dummies.index:
    all_ind_dums2.append(dic_ind_translate[ind.split(' x ')[1]])
    all_year_dums2.append(int(ind.split(' x ')[0].replace('$\\delta_{','').replace("}$","")))
table_dummies['year'] = all_year_dums2
table_dummies['ind'] = all_ind_dums2

# %%
table_dummies_f = table_dummies_f.set_index(['year','ind'])
table_dummies_f.head()
# Out:
#                              25th pctl 50th pctl 75th pctl  sig 25  sig 50  \
# year ind
# 2020 agriculture                -0.513    -1.193    -0.701    0.01    0.05
#      manufactures, primary       0.463     0.367     0.149    0.10    1.00
#      extractive and energy      -0.032     0.416     0.946    1.00    1.00
#      manufactures, secondary    -1.110    -1.770     0.576    0.10    1.00
#      construction               -0.585    -3.019     0.181    1.00    0.01
#
#                               sig 75
# year ind
# 2020 agriculture                1.00
#      manufactures, primary      1.00
#      extractive and energy      0.05
#      manufactures, secondary    1.00
#      construction               1.00

# %%
table_dummies = table_dummies.set_index(['year','ind'])
table_dummies.head()
# Out:
#                              25th pctl 50th pctl 75th pctl  sig 25  sig 50  \
# year ind
# 2020 agriculture                 0.511    -0.378     0.739    0.01    0.10
#      manufactures, primary      -0.465    -1.563    -0.390    0.01    0.01
#      extractive and energy       0.278    -0.992     0.008    0.05    0.05
#      manufactures, secondary     0.105    -0.507     0.052    1.00    1.00
#      construction                0.666     0.765     2.147    0.01    0.01
#
#                               sig 75
# year ind
# 2020 agriculture                1.00
#      manufactures, primary      1.00
#      extractive and energy      1.00
#      manufactures, secondary    1.00
#      construction               0.01

# %% [markdown]
# ### Reading employment data

# %%
path = 'descriptive_stats/'

file_split('stocks_E_industry_w.log',path,startwords=['ciclo',],endword="Total",header=None)

tab_e_ind_1 = read_table(path+'stocks_E_industry_w_1.log',keyword='ciclo',rescale=100,ncols=6)
tab_e_ind_2 = read_table(path+'stocks_E_industry_w_2.log',keyword='ciclo',rescale=100,ncols=4)
tab_e_ind = pd.concat((tab_e_ind_1,tab_e_ind_2),axis=1)
tab_e_ind.rename(columns=industry_dict,inplace=True)
tab_e_ind.rename(index=date_dict,inplace=True)
tab_e_ind.head()
# Out:
#         agriculture  manufactures, primary  extractive and energy  \
# 2005Q1    473715.07              994533.00             1035476.59
# 2005Q2    499959.89             1007007.37             1051515.39
# 2005Q3    506896.23             1006269.15             1076158.88
# 2005Q4    525850.30             1009786.14             1086961.30
# 2006Q1    508519.95              969445.08             1088810.74
#
#         manufactures, secondary  construction  hospitality and sales  \
# 2005Q1                839644.48    1814072.71             2915322.75
# 2005Q2                846258.53    1875225.69             3067829.12
# 2005Q3                870718.23    1920187.68             3143106.60
# 2005Q4                824566.82    1939860.91             3144373.66
# 2006Q1                849166.47    1947958.32             3102377.87
#
#         Transport, storage and IT.  Financial and prof. serv.  \
# 2005Q1                   891234.56                 1673224.13
# 2005Q2                   893954.68                 1785085.40
# 2005Q3                   920963.75                 1794988.45
# 2005Q4                   908474.94                 1847232.28
# 2006Q1                   913945.53                 1874000.16
#
#         Education and healthcare  Other services
# 2005Q1                3301773.86      1272331.89
# 2005Q2                3348945.49      1313956.69
# 2005Q3                3355164.74      1374849.44
# 2005Q4                3409273.70      1328851.90
# 2006Q1                3435714.02      1378562.25

# %%
av_19 = np.average(tab_e_ind.loc['2019Q1':'2019Q4',:].values,axis=0)
diff = tab_e_ind.iloc[1:,:].values-tab_e_ind.iloc[:-1,:].values
diff_19 = tab_e_ind.iloc[:,:].values-av_19

tab_e_ind_change = pd.DataFrame(diff,columns=tab_e_ind.keys(),index=tab_e_ind.index[1:])
tab_e_ind_change_rel = pd.DataFrame(diff/tab_e_ind.iloc[:-1,:].values,columns=tab_e_ind.keys(),index=tab_e_ind.index[1:])

tab_e_ind_change19 = pd.DataFrame(diff_19,columns=tab_e_ind.keys(),index=tab_e_ind.index[:])
tab_e_ind_change19_rel = pd.DataFrame(diff_19/av_19,columns=tab_e_ind.keys(),index=tab_e_ind.index[:])

tab_e_ind_change19_rel.head()
# Out:
#         agriculture  manufactures, primary  extractive and energy  \
# 2005Q1    -0.041172               0.257779               0.065548
# 2005Q2     0.011949               0.273555               0.082052
# 2005Q3     0.025988               0.272621               0.107412
# 2005Q4     0.064352               0.277069               0.118528
# 2006Q1     0.029275               0.226050               0.120431
#
#         manufactures, secondary  construction  hospitality and sales  \
# 2005Q1                 0.099594      0.917041              -0.224023
# 2005Q2                 0.108256      0.981665              -0.183430
# 2005Q3                 0.140288      1.029179              -0.163393
# 2005Q4                 0.079849      1.049969              -0.163056
# 2006Q1                 0.112064      1.058526              -0.174234
#
#         Transport, storage and IT.  Financial and prof. serv.  \
# 2005Q1                   -0.364629                  -0.198323
# 2005Q2                   -0.362689                  -0.144728
# 2005Q3                   -0.343434                  -0.139984
# 2005Q4                   -0.352338                  -0.114953
# 2006Q1                   -0.348438                  -0.102127
#
#         Education and healthcare  Other services
# 2005Q1                 -0.215100        0.017319
# 2005Q2                 -0.203886        0.050601
# 2005Q3                 -0.202408        0.099289
# 2005Q4                 -0.189545        0.062511
# 2006Q1                 -0.183260        0.102258

# %%
T = 2023-2005
year_changes19 = np.zeros((T,10))
for i,year in enumerate(range(2005,2023)):
    year_changes19[i,:] = np.average(tab_e_ind_change19_rel.loc[str(year)+"Q1":str(year)+"Q4",:],axis=0)
table_e_ind_change19_rel_y= pd.DataFrame(year_changes19,columns=tab_e_ind_change19_rel.keys(),index=np.arange(2005,2023))

sn.set_palette('tab10',10)
plt.figure(figsize=(12,8))
for ind in industry_dict.values():
    plt.plot(table_e_ind_change19_rel_y.loc[:,ind],label=ind)
plt.legend()
# plt.axvline('2020Q1')
plt.axhline(c='k')
plt.xticks(np.arange(2005,2023))
plt.show()

# %%
table_e_ind_change19_rel_y.head()
# Out:
#       agriculture  manufactures, primary  extractive and energy  \
# 2005     0.015279               0.270256               0.093385
# 2006    -0.011318               0.227566               0.133173
# 2007     0.005834               0.169494               0.132911
# 2008    -0.138652               0.074869               0.210751
# 2009    -0.146693              -0.063117               0.029005
#
#       manufactures, secondary  construction  hospitality and sales  \
# 2005                 0.106997      0.994463              -0.183476
# 2006                 0.116343      1.146313              -0.134152
# 2007                 0.147798      1.296175              -0.091566
# 2008                 0.101797      1.039793              -0.078999
# 2009                -0.013642      0.526856              -0.122280
#
#       Transport, storage and IT.  Financial and prof. serv.  \
# 2005                   -0.355773                  -0.149497
# 2006                   -0.329611                  -0.079718
# 2007                   -0.309594                  -0.008250
# 2008                   -0.086668                  -0.047421
# 2009                   -0.117828                  -0.073836
#
#       Education and healthcare  Other services
# 2005                 -0.202735        0.057430
# 2006                 -0.184701        0.121854
# 2007                 -0.164981        0.145174
# 2008                 -0.140981        0.035112
# 2009                 -0.097408        0.004156

# %%
table_dummies_f.loc[2021]
# Out:
#                            25th pctl 50th pctl 75th pctl  sig 25  sig 50  \
# ind
# agriculture                   -0.636    -2.466    -1.616    0.01    0.01
# manufactures, primary         -0.617    -2.538    -3.809    1.00    0.01
# extractive and energy         -0.400    -0.558    -0.629    1.00    1.00
# manufactures, secondary       -1.453    -3.087    -0.929    0.01    0.01
# construction                  -0.516    -3.021    -2.924    1.00    0.05
# hospitality and sales         -0.839    -1.537    -0.357    0.01    0.01
# Transport, storage and IT.    -0.859     0.272    -0.445    0.01    1.00
# Financial and prof. serv.     -1.255    -3.006    -2.008    0.01    0.01
# Education and healthcare      -0.234    -2.983    -0.225    1.00    0.01
# Other services                -0.522    -2.627    -0.291    1.00    0.01
#
#                             sig 75
# ind
# agriculture                   1.00
# manufactures, primary         0.01
# extractive and energy         1.00
# manufactures, secondary       1.00
# construction                  0.10
# hospitality and sales         1.00
# Transport, storage and IT.    1.00
# Financial and prof. serv.     0.01
# Education and healthcare      1.00
# Other services                1.00

# %%
def significance_stars(sig):
    if sig <=0.01:
        sigg = '$^{***}$'
    elif sig <=0.05:
        sigg = '$^{**}$'
    elif sig <=0.1:
        sigg = '$^{*}$'
    else:
        sigg = ''
    return sigg

# %%
colors = sn.color_palette('viridis',10)
ind_acronyms = ['AGRI','MAN1','EXTR','MAN2','CONS','HOSP','TSIT','FINP','EDHC','OTHS']
color_dict = dict(zip(industry_dict.values(),colors))
size_dict = dict(zip(industry_dict.values(),1000*av_19/np.sum(av_19)))
acro_dict = dict(zip(industry_dict.values(),ind_acronyms))
plt.figure(figsize=(15,4))
for i,year in enumerate([2020,2021,2022]):
    plt.subplot(131+i)
    plt.title(year,fontsize=16)
    for ind in table_dummies_f.loc[year,:].index:
        sig = significance_stars(table_dummies_f.loc[(year,ind),'sig 25'])
        plt.scatter(table_e_ind_change19_rel_y.loc[year,ind],float(table_dummies_f.loc[(year,ind),'25th pctl']),
                    color=color_dict[ind],s=size_dict[ind],label=acro_dict[ind]+": "+ind)
        plt.annotate(acro_dict[ind]+sig,
                     xy=(table_e_ind_change19_rel_y.loc[year,ind],float(table_dummies_f.loc[(year,ind),'25th pctl'])-0.05))
    plt.ylim(-2,1)
    plt.xlim(-0.1,0.2)
    plt.axvline(c='k',lw=1)
    plt.axhline(c='k',lw=1)
    if year == 2020:
        plt.legend(ncol=3,fontsize=12,bbox_to_anchor=(3.,-0.15))
# plt.tight_layout()
plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(15,15))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in table_dummies_f.loc[year,:].index:
            sig = significance_stars(table_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(table_e_ind_change19_rel_y.loc[year,ind],
                        float(table_dummies_f.loc[(year,ind),'{}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind,alpha=0.6)
            plt.annotate(acro_dict[ind]+sig,xy=(table_e_ind_change19_rel_y.loc[year,ind],
                                                float(table_dummies_f.loc[(year,ind),'{}th pctl'.format(pct)])-0.05))
        plt.ylim(-4,2)
        plt.xlim(-0.1,0.2)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        plt.ylabel(r"$\delta_{"+str(year)+"}$ x female")
        if xx >336:
            plt.xlabel(r'$\Delta$ Employment$_{2019}$')
plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(.7,-0.15))
plt.savefig('./plots_stocks/scatter_indE_mother_penalty.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
# sn.set_palette('tab10',10)
# plt.figure(figsize=(15,15))
# for j,pct in enumerate([25,50,75]):
#     for i,year in enumerate([2020,2021,2022]):
#         xx = 331+i+(j*3)
#         plt.subplot(xx)
#         plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
#         for ind in tab_dummies_f.loc[year,:].index:
#             sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
#             plt.scatter(tab_e_ind_change19_rel_y.loc[year,ind],
#                         float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
#                         s=size_dict[ind],label=acro_dict[ind]+": "+ind,alpha=0.6)
#             plt.annotate(acro_dict[ind]+sig,xy=(tab_e_ind_change19_rel_y.loc[year,ind],
#                                                 float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
#         plt.ylim(-4,2)
#         plt.xlim(-0.1,0.2)
#         plt.axvline(c='k',lw=1)
#         plt.axhline(c='k',lw=1)
#         plt.ylabel(r"$\delta_{"+str(year)+"}$ x female")
#         if xx >336:
#             plt.xlabel(r'$\Delta$ Employment$_{2019}$')
# plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(.7,-0.15))
# plt.savefig('./plots_stocks/scatter_indE_mother_penalty_with_disc.pdf',format='pdf',bbox_inches='tight')
# plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(16,17))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies_f.loc[year,:].index:
            sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
                        float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,xy=(float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
                                                 float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
        plt.ylim(-4,4)
        plt.xlim(-4,4)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        plt.xlabel(r"$\delta_{"+str(year)+"}$")
#         if xx >336:
        plt.ylabel(r"$\delta_{"+str(year)+"}$ x female")
# plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.tight_layout()
# plt.savefig('./plots_stocks/scatter_indE_mother_father_dummies.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
sn.set_palette('viridis',10)
plt.figure(figsize=(16,17))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in table_dummies_f.loc[year,:].index:
            sig = significance_stars(table_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
            base_point = float(table_dummies.loc[(year,ind),'{}th pctl'.format(pct)])
            plt.scatter(base_point,base_point+float(table_dummies_f.loc[(year,ind),'{}th pctl'.format(pct)]),
                        color=color_dict[ind],s=size_dict[ind],label=acro_dict[ind]+": "+ind,alpha=0.8)
            plt.annotate(acro_dict[ind]+sig,
                         xy=(base_point,base_point+float(table_dummies_f.loc[(year,ind),'{}th pctl'.format(pct)])-0.05))
            plt.plot([-4,4],[-4,4], color='grey',lw=1)
        plt.ylim(-4,4)
        plt.xlim(-4,4)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        plt.xlabel(r"$\delta_{"+str(year)+"}$")
#         if xx >336:
        plt.ylabel(r"$\delta_{"+str(year)+"}$ + "+r"$\delta_{"+str(year)+"}$ x female")
plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(.7,-0.15))
# plt.tight_layout()
plt.savefig('./plots_stocks/scatter_indE_mother_father_dummies45.pdf',format='pdf',bbox_inches='tight')
plt.show()

# %%
# sn.set_palette('viridis',10)
# plt.figure(figsize=(16,17))
# for j,pct in enumerate([25,50,75]):
#     for i,year in enumerate([2020,2021,2022]):
#         xx = 331+i+(j*3)
#         plt.subplot(xx)
#         plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
#         for ind in tab_dummies_f.loc[year,:].index:
#             sig = significance_stars(tab_dummies_f.loc[(year,ind),'sig {}'.format(pct)])
#             base_point = float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)])
#             plt.scatter(base_point,base_point+float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),
#                         color=color_dict[ind],s=size_dict[ind],label=acro_dict[ind]+": "+ind,alpha=0.8)
#             plt.annotate(acro_dict[ind]+sig,
#                          xy=(base_point,base_point+float(tab_dummies_f.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
#             plt.plot([-4,3],[-4,3], color='grey',lw=1)
#         plt.ylim(-4,3)
#         plt.xlim(-4,3)
#         plt.axvline(c='k',lw=1)
#         plt.axhline(c='k',lw=1)
#         plt.xlabel(r"$\delta_{"+str(year)+"}$")
# #         if xx >336:
#         plt.ylabel(r"$\delta_{"+str(year)+"}$ + "+r"$\delta_{"+str(year)+"}$ x female")
# plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(.7,-0.15))
# # plt.tight_layout()
# plt.savefig('./plots_stocks/scatter_indE_mother_father_dummies45_withdisc.pdf',format='pdf',bbox_inches='tight')
# plt.show()

# %%
sn.set_palette('tab10',10)
plt.figure(figsize=(15,15))
for j,pct in enumerate([25,50,75]):
    for i,year in enumerate([2020,2021,2022]):
        xx = 331+i+(j*3)
        plt.subplot(xx)
        plt.title(str(year)+" {}th pctle".format(pct),fontsize=16)
        for ind in tab_dummies.loc[year,:].index:
            sig = significance_stars(tab_dummies.loc[(year,ind),'sig {}'.format(pct)])
            plt.scatter(tab_e_ind_change19_rel_y.loc[year,ind],
                        float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)]),color=color_dict[ind],
                        s=size_dict[ind],label=acro_dict[ind]+": "+ind)
            plt.annotate(acro_dict[ind]+sig,xy=(tab_e_ind_change19_rel_y.loc[year,ind],
                                                float(tab_dummies.loc[(year,ind),'Parents, {}th pctl'.format(pct)])-0.05))
        plt.ylim(-2,4)
        plt.xlim(-0.1,0.2)
        plt.axvline(c='k',lw=1)
        plt.axhline(c='k',lw=1)
        if xx >336:
            plt.xlabel(r'$\Delta$ Employment$_{2019}$')
plt.legend(fontsize=12,ncol=3,bbox_to_anchor=(1.,-0.2))
plt.savefig('./plots_stocks/scatter_indE.pdf',format='pdf',bbox_inches='tight')
plt.show()
